# %% [markdown]
# ![panda](http://res.freestockphotos.biz/thumbs/3/3173-illustration-of-a-giant-panda-eating-bamboo-th.png)

# %% [markdown]
# # Pandas Data Cleaning

# %% [markdown]
# # Objectives

# %% [markdown]
# - Handle missing data, and recognize when different strategies for handling missing data would be appropriate
# - Use DataFrame methods (and sometimes lambda functions) to transform data
# - Use string methods to transform object-type columns

# %%
# Imports

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## To The Center!
#
# That's right - we're still working with Austin Animal Center data! But now, let's check out the Outcomes data, instead of the Intakes data we were working with before.
#
# Data source: https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238

# %%
# Read in the animal center outcomes data as df
# Can use parse_dates and pass a column name to read it as a datetime
df = pd.read_csv('data/Austin_Animal_Center_Outcomes_022822.csv', 
                 parse_dates=['DateTime', 'Date of Birth'])
# Out:
# /var/folders/0c/wkrr_xjn2xz65fx41rj45h6w0000gp/T/ipykernel_4654/484559865.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('data/Austin_Animal_Center_Outcomes_022822.csv',

# %%
# Check it out
df.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %%
# Info on the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137097 entries, 0 to 137096
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         137097 non-null  object
#  1   Name              96095 non-null   object
#  2   DateTime          137097 non-null  datetime64[ns]
#  3   MonthYear         137097 non-null  object
#  4   Date of Birth     137097 non-null  datetime64[ns]
#  5   Outcome Type      137073 non-null  object
#  6   Outcome Subtype   62653 non-null   object
#  7   Animal Type       137097 non-null  object
#  8   Sex upon Outcome  137095 non-null  object
#  9   Age upon Outcome  137092 non-null  object
#  10  Breed             137097 non-null  object
#  11  Color             137097 non-null  object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 12.6+ MB

# %%
df.shape
# Out:
# (137097, 12)

# %%
df.describe(include=['object'])
# Out:
#        Animal ID   Name MonthYear Outcome Type Outcome Subtype Animal Type  \
# count     137097  96095    137097       137073           62653      137097
# unique    122587  23022       101            9              26           5
# top      A721033    Max  Jun 2019     Adoption         Partner         Dog
# freq          33    617      2244        62707           33259       77091
#
#        Sex upon Outcome Age upon Outcome                   Breed        Color
# count            137095           137092                  137097       137097
# unique                5               53                    2735          617
# top       Neutered Male           1 year  Domestic Shorthair Mix  Black/White
# freq              48299            23780                   32387        14315

# %% [markdown]
# ## Using Questions to Drive Both Exploration and Cleaning
#
# The best way to think about how to both explore and clean your data set is to think about what is interesting in your data, what questions you have, what you want to know and how to actually get there. We're going to ask a few questions of our dataset, and use that to drive our 'cleaning' process (and talk a little bit about how and when to clean data in the process!)

# %% [markdown]
# ## Question 1: How old are the animals in our dataset?

# %% [markdown]
# Let's try to answer this with the `Age upon Outcome` variable:

# %%
df['Age upon Outcome'].value_counts()
# Out:
# Age upon Outcome
# 1 year       23780
# 2 years      21332
# 2 months     17063
# 3 years       8112
# 3 months      6685
# 1 month       5902
# 4 years       4765
# 4 months      4502
# 5 years       4413
# 5 months      3436
# 6 months      3329
# 6 years       2925
# 8 years       2551
# 7 years       2527
# 3 weeks       2331
# 2 weeks       2294
# 8 months      2177
# 10 years      2045
# 10 months     1988
# 4 weeks       1938
# 7 months      1777
# 9 months      1415
# 9 years       1410
# 1 weeks        995
# 12 years       995
# 11 months      869
# 11 years       801
# 1 week         748
# 13 years       656
# 14 years       441
# 3 days         399
# 2 days         389
# 15 years       369
# 1 day          316
# 6 days         263
# 4 days         250
# 0 years        207
# 5 days         167
# 16 years       163
# 5 weeks        152
# 17 years        92
# 18 years        56
# 19 years        27
# 20 years        21
# -1 years         6
# 22 years         6
# 23 years         1
# 24 years         1
# -2 years         1
# 25 years         1
# 21 years         1
# -3 years         1
# 30 years         1
# Name: count, dtype: int64

# %% [markdown]
# Oh no! These aren't numbers! And the data is pretty dirty! Let's see how we can break this column apart, into the Age Number and the Age Unit.

# %%
df['Age upon Outcome'].str.split(" ")
# Out:
# 0          [2, years]
# 1           [1, year]
# 2           [1, year]
# 3         [4, months]
# 4           [6, days]
#              ...
# 137092    [2, months]
# 137093     [2, years]
# 137094      [1, year]
# 137095     [8, years]
# 137096     [3, years]
# Name: Age upon Outcome, Length: 137097, dtype: object

# %%
# Split out the age number and age unit - using string methods!
df['Age Number'] = df['Age upon Outcome'].str.split(" ").str[0]
df['Age Unit'] = df['Age upon Outcome'].str.split(" ").str[1]

# %%
# Sanity check
df.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color Age Number Age Unit
# 0              Domestic Shorthair Mix  Brown Tabby/White          2    years
# 1             Chihuahua Shorthair Mix        White/Brown          1     year
# 2                             Raccoon               Gray          1     year
# 3  Anatol Shepherd/Labrador Retriever               Buff          4   months
# 4              Domestic Shorthair Mix       Orange Tabby          6     days

# %%
# Check the data types really quick...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137097 entries, 0 to 137096
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         137097 non-null  object
#  1   Name              96095 non-null   object
#  2   DateTime          137097 non-null  datetime64[ns]
#  3   MonthYear         137097 non-null  object
#  4   Date of Birth     137097 non-null  datetime64[ns]
#  5   Outcome Type      137073 non-null  object
#  6   Outcome Subtype   62653 non-null   object
#  7   Animal Type       137097 non-null  object
#  8   Sex upon Outcome  137095 non-null  object
#  9   Age upon Outcome  137092 non-null  object
#  10  Breed             137097 non-null  object
#  11  Color             137097 non-null  object
#  12  Age Number        137092 non-null  object
#  13  Age Unit          137092 non-null  object
# dtypes: datetime64[ns](2), object(12)
# memory usage: 14.6+ MB

# %%
df.dtypes
# Out:
# Animal ID                   object
# Name                        object
# DateTime            datetime64[ns]
# MonthYear                   object
# Date of Birth       datetime64[ns]
# Outcome Type                object
# Outcome Subtype             object
# Animal Type                 object
# Sex upon Outcome            object
# Age upon Outcome            object
# Breed                       object
# Color                       object
# Age Number                  object
# Age Unit                    object
# dtype: object

# %%
# Need to make our Age Number actual numbers! 
df['Age Number'].astype(int)
# But this throws an error!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Need to make our Age Number actual numbers!
# ----> 2 df['Age Number'].astype(int)
#       3 # But this throws an error!
#
# File ~/miniconda3/envs/Cohort_Env/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/miniconda3/envs/Cohort_Env/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/miniconda3/envs/Cohort_Env/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/miniconda3/envs/Cohort_Env/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/miniconda3/envs/Cohort_Env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/miniconda3/envs/Cohort_Env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/Cohort_Env/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# Alas! Nulls! Let's check out these null values:

# %%
# Check how many nulls we have in our original Age Upon Outcome column
df.isna().sum()
# Out:
# Animal ID               0
# Name                41002
# DateTime                0
# MonthYear               0
# Date of Birth           0
# Outcome Type           24
# Outcome Subtype     74444
# Animal Type             0
# Sex upon Outcome        2
# Age upon Outcome        5
# Breed                   0
# Color                   0
# Age Number              5
# Age Unit                5
# dtype: int64

# %%
df['Age Number'].isna().sum()
# Out:
# 5

# %% [markdown]
# ### Handling Missing Data

# %% [markdown]
# A lot of the times we'll have missing information in our data set. This can sometimes be troublesome in what we're trying to do.

# %% [markdown]
# There are a few strategies we can choose from and they each have their pros/cons:
#
# - **Fill with a Relevant Value**
#     - If we know what the nulls 'should' be, easy to fill them with that value
#     - For numbers, perhaps the null indicates a 0
#     - Or, for string columns, might be easier to handle if we fill with "Missing" or "Unknown"
# - **Fill with a Reasonable Value**
#     - For numeric data, it might be acceptable to fill with a measure of central tendency (mean or median)
#     - For categorical/string data, might be acceptable to fill with the most common (mode)
#     - But beware! Filling in missing values can lead to you drawing incorrect conclusions. If most of the data from a column are missing, it's going to appear that the value you filled it in with is more common that it actually was!
# - **Specify Missing Data**
#     - If you plan to fill in missing values, it might make sense to specify that the data was originally missing by creating a new indicator column
#     - This can be helpful when you suspect that the fact the data was missing could be important for an analysis.
# - **Drop Missing Data**
#     - While you should try to keep as much relevant data as possible, sometimes the other methods don't make as much sense and it's better to remove or **drop** the missing data
#     - We typically drop missing data if very little data would be lost and/or trying to fill in the values wouldn't make sense for our use case

# %% [markdown]
# So: what should we do about the missing Age upon Outcome data?
#
# <br>
# <details>
#     <summary>Possible Answer</summary>
#
# - It's probably okay to drop the missing data in this case - not very many rows with nulls in that column
# - Should look at the percentage of the total (aka what percentage of rows would be dropped) to justify this decision
#
#
# Note! There is a Date of Birth column that does not have any nulls! But we're specifically trying to use Age Upon Outcome here because it helps us practice some other tactics for cleaning data.
#
# </details>

# %%
# No matter what - better to make this change on a COPY of the dataframe
df_clean = df.copy()

# %%
# Code here to handle nulls
df_clean = df_clean.dropna(subset=['Age upon Outcome'])

# %%
# Sanity check
df_clean.isna().sum()
# Out:
# Animal ID               0
# Name                40999
# DateTime                0
# MonthYear               0
# Date of Birth           0
# Outcome Type           23
# Outcome Subtype     74443
# Animal Type             0
# Sex upon Outcome        1
# Age upon Outcome        0
# Breed                   0
# Color                   0
# Age Number              0
# Age Unit                0
# dtype: int64

# %%
df_clean2 = df.dropna()
df_clean2.isna().sum()
# Out:
# Animal ID           0
# Name                0
# DateTime            0
# MonthYear           0
# Date of Birth       0
# Outcome Type        0
# Outcome Subtype     0
# Animal Type         0
# Sex upon Outcome    0
# Age upon Outcome    0
# Breed               0
# Color               0
# Age Number          0
# Age Unit            0
# dtype: int64

# %%
df_clean2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32394 entries, 6 to 137095
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Animal ID         32394 non-null  object
#  1   Name              32394 non-null  object
#  2   DateTime          32394 non-null  datetime64[ns]
#  3   MonthYear         32394 non-null  object
#  4   Date of Birth     32394 non-null  datetime64[ns]
#  5   Outcome Type      32394 non-null  object
#  6   Outcome Subtype   32394 non-null  object
#  7   Animal Type       32394 non-null  object
#  8   Sex upon Outcome  32394 non-null  object
#  9   Age upon Outcome  32394 non-null  object
#  10  Breed             32394 non-null  object
#  11  Color             32394 non-null  object
#  12  Age Number        32394 non-null  object
#  13  Age Unit          32394 non-null  object
# dtypes: datetime64[ns](2), object(12)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# Animal ID               0
# Name                41002
# DateTime                0
# MonthYear               0
# Date of Birth           0
# Outcome Type           24
# Outcome Subtype     74444
# Animal Type             0
# Sex upon Outcome        2
# Age upon Outcome        5
# Breed                   0
# Color                   0
# Age Number              5
# Age Unit                5
# dtype: int64

# %%
df_clean2['Age Number'] = df_clean2['Age Number'].astype(int)
# Out:
# /var/folders/0c/wkrr_xjn2xz65fx41rj45h6w0000gp/T/ipykernel_4654/1724090904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean2['Age Number'] = df_clean2['Age Number'].astype(int)

# %%
# Cool - now we can make our Age Number column an integer
df_clean['Age Number'] = df_clean['Age Number'].astype(int)

# %%
df.isna().sum()
# Out:
# Animal ID               0
# Name                41002
# DateTime                0
# MonthYear               0
# Date of Birth           0
# Outcome Type           24
# Outcome Subtype     74444
# Animal Type             0
# Sex upon Outcome        2
# Age upon Outcome        5
# Breed                   0
# Color                   0
# Age Number              5
# Age Unit                5
# dtype: int64

# %%
# Sanity check
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 137092 entries, 0 to 137096
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         137092 non-null  object
#  1   Name              96093 non-null   object
#  2   DateTime          137092 non-null  datetime64[ns]
#  3   MonthYear         137092 non-null  object
#  4   Date of Birth     137092 non-null  datetime64[ns]
#  5   Outcome Type      137069 non-null  object
#  6   Outcome Subtype   62649 non-null   object
#  7   Animal Type       137092 non-null  object
#  8   Sex upon Outcome  137091 non-null  object
#  9   Age upon Outcome  137092 non-null  object
#  10  Breed             137092 non-null  object
#  11  Color             137092 non-null  object
#  12  Age Number        137092 non-null  int64
#  13  Age Unit          137092 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(11)
# memory usage: 15.7+ MB

# %% [markdown]
# Now let's do something about those Age Values...

# %%
# Drop full column
df.drop(columns=['Outcome Subtype'])
# Out:
#        Animal ID       Name            DateTime MonthYear Date of Birth  \
# 0        A794011      Chunk 2019-05-08 18:20:00  May 2019    2017-05-02
# 1        A776359      Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12
# 2        A821648        NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16
# 3        A720371      Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08
# 4        A674754        NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12
# ...          ...        ...                 ...       ...           ...
# 137092   A850166     Rainey 2022-01-24 18:20:00  Jan 2022    2021-11-19
# 137093   A852031     Noodle 2022-02-28 12:50:00  Feb 2022    2020-02-23
# 137094   A845839    *Carmen 2022-02-28 13:49:00  Feb 2022    2020-05-05
# 137095   A844321  Mia Marie 2022-02-28 13:04:00  Feb 2022    2013-10-15
# 137096   A813933    Lucille 2022-02-28 14:19:00  Feb 2022    2018-12-21
#
#        Outcome Type Animal Type Sex upon Outcome Age upon Outcome  \
# 0         Rto-Adopt         Cat    Neutered Male          2 years
# 1          Adoption         Dog    Neutered Male           1 year
# 2        Euthanasia       Other          Unknown           1 year
# 3          Adoption         Dog    Neutered Male         4 months
# 4          Transfer         Cat      Intact Male           6 days
# ...             ...         ...              ...              ...
# 137092     Adoption         Cat      Intact Male         2 months
# 137093     Transfer         Dog    Neutered Male          2 years
# 137094     Adoption         Dog    Spayed Female           1 year
# 137095     Adoption         Dog    Spayed Female          8 years
# 137096     Adoption         Dog    Spayed Female          3 years
#
#                                      Breed              Color Age Number  \
# 0                   Domestic Shorthair Mix  Brown Tabby/White          2
# 1                  Chihuahua Shorthair Mix        White/Brown          1
# 2                                  Raccoon               Gray          1
# 3       Anatol Shepherd/Labrador Retriever               Buff          4
# 4                   Domestic Shorthair Mix       Orange Tabby          6
# ...                                    ...                ...        ...
# 137092                             Siamese         Seal Point          2
# 137093       Pomeranian/Chihuahua Longhair               Buff          2
# 137094                        Pit Bull Mix              Brown          1
# 137095                            Pit Bull        Black/White          8
# 137096                    Belgian Malinois        Brown/Black          3
#
#        Age Unit
# 0         years
# 1          year
# 2          year
# 3        months
# 4          days
# ...         ...
# 137092   months
# 137093    years
# 137094     year
# 137095    years
# 137096    years
#
# [137097 rows x 13 columns]

# %%
df_clean.fillna('Some Value')
# Out:
#        Animal ID        Name            DateTime MonthYear Date of Birth  \
# 0        A794011       Chunk 2019-05-08 18:20:00  May 2019    2017-05-02
# 1        A776359       Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12
# 2        A821648  Some Value 2020-08-16 11:38:00  Aug 2020    2019-08-16
# 3        A720371       Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08
# 4        A674754  Some Value 2014-03-18 11:47:00  Mar 2014    2014-03-12
# ...          ...         ...                 ...       ...           ...
# 137092   A850166      Rainey 2022-01-24 18:20:00  Jan 2022    2021-11-19
# 137093   A852031      Noodle 2022-02-28 12:50:00  Feb 2022    2020-02-23
# 137094   A845839     *Carmen 2022-02-28 13:49:00  Feb 2022    2020-05-05
# 137095   A844321   Mia Marie 2022-02-28 13:04:00  Feb 2022    2013-10-15
# 137096   A813933     Lucille 2022-02-28 14:19:00  Feb 2022    2018-12-21
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0         Rto-Adopt      Some Value         Cat    Neutered Male
# 1          Adoption      Some Value         Dog    Neutered Male
# 2        Euthanasia      Some Value       Other          Unknown
# 3          Adoption      Some Value         Dog    Neutered Male
# 4          Transfer         Partner         Cat      Intact Male
# ...             ...             ...         ...              ...
# 137092     Adoption      Some Value         Cat      Intact Male
# 137093     Transfer         Partner         Dog    Neutered Male
# 137094     Adoption          Foster         Dog    Spayed Female
# 137095     Adoption          Foster         Dog    Spayed Female
# 137096     Adoption      Some Value         Dog    Spayed Female
#
#        Age upon Outcome                               Breed  \
# 0               2 years              Domestic Shorthair Mix
# 1                1 year             Chihuahua Shorthair Mix
# 2                1 year                             Raccoon
# 3              4 months  Anatol Shepherd/Labrador Retriever
# 4                6 days              Domestic Shorthair Mix
# ...                 ...                                 ...
# 137092         2 months                             Siamese
# 137093          2 years       Pomeranian/Chihuahua Longhair
# 137094           1 year                        Pit Bull Mix
# 137095          8 years                            Pit Bull
# 137096          3 years                    Belgian Malinois
#
#                     Color  Age Number Age Unit
# 0       Brown Tabby/White           2    years
# 1             White/Brown           1     year
# 2                    Gray           1     year
# 3                    Buff           4   months
# 4            Orange Tabby           6     days
# ...                   ...         ...      ...
# 137092         Seal Point           2   months
# 137093               Buff           2    years
# 137094              Brown           1     year
# 137095        Black/White           8    years
# 137096        Brown/Black           3    years
#
# [137092 rows x 14 columns]

# %% [markdown]
# ### Map, Apply and Applymap

# %% [markdown]
# Resource: https://www.geeksforgeeks.org/difference-between-map-applymap-and-apply-methods-in-pandas/
#
# The `.map()` method applies a transformation to every entry in the Series. This transformation  "maps" each value from the Series to a new value. A transformation can be defined by a function, Series, or dictionary.
#
# The `.apply()` method is similar to the `.map()` method for Series, but can only take in functions.
#
# The `.applymap()` method only works on DataFrames, and applies the same transformation to every element (cell) of that DataFrame.

# %%
df_clean.applymap(type)
# Out:
# /var/folders/0c/wkrr_xjn2xz65fx41rj45h6w0000gp/T/ipykernel_4654/1430783967.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_clean.applymap(type)
#             Animal ID             Name  \
# 0       <class 'str'>    <class 'str'>
# 1       <class 'str'>    <class 'str'>
# 2       <class 'str'>  <class 'float'>
# 3       <class 'str'>    <class 'str'>
# 4       <class 'str'>  <class 'float'>
# ...               ...              ...
# 137092  <class 'str'>    <class 'str'>
# 137093  <class 'str'>    <class 'str'>
# 137094  <class 'str'>    <class 'str'>
# 137095  <class 'str'>    <class 'str'>
# 137096  <class 'str'>    <class 'str'>
#
#                                                  DateTime      MonthYear  \
# 0       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 1       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 2       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 3       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 4       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# ...                                                   ...            ...
# 137092  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137093  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137094  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137095  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137096  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
#
#                                             Date of Birth   Outcome Type  \
# 0       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 1       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 2       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 3       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 4       <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# ...                                                   ...            ...
# 137092  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137093  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137094  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137095  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 137096  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
#
#         Outcome Subtype    Animal Type Sex upon Outcome Age upon Outcome  \
# 0       <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 1       <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 2       <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 3       <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 4         <class 'str'>  <class 'str'>    <class 'str'>    <class 'str'>
# ...                 ...            ...              ...              ...
# 137092  <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 137093    <class 'str'>  <class 'str'>    <class 'str'>    <class 'str'>
# 137094    <class 'str'>  <class 'str'>    <class 'str'>    <class 'str'>
# 137095    <class 'str'>  <class 'str'>    <class 'str'>    <class 'str'>
# 137096  <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
#
#                 Breed          Color     Age Number       Age Unit
# 0       <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 1       <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 2       <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 3       <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 4       <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# ...               ...            ...            ...            ...
# 137092  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 137093  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 137094  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 137095  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
# 137096  <class 'str'>  <class 'str'>  <class 'int'>  <class 'str'>
#
# [137092 rows x 14 columns]

# %%
# Providing this dictionary to capture age values in # days (not perfect)
age_vals = {
    'years': 365,
    'year': 365,
    'months': 30,
    'month': 30,
    'weeks': 7,
    'week': 7,
    'days': 1,
    'day': 1
}
age_vals
# Out:
# {'years': 365,
#  'year': 365,
#  'months': 30,
#  'month': 30,
#  'weeks': 7,
#  'week': 7,
#  'days': 1,
#  'day': 1}

# %%
df_clean2['Age Unit'].replace(age_vals)
# Out:
# /var/folders/0c/wkrr_xjn2xz65fx41rj45h6w0000gp/T/ipykernel_4654/315443454.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_clean2['Age Unit'].replace(age_vals)
# 6         365
# 13        365
# 15          7
# 16         30
# 21        365
#          ...
# 137086     30
# 137087    365
# 137093    365
# 137094    365
# 137095    365
# Name: Age Unit, Length: 32394, dtype: int64

# %%
df_clean['Age Unit'].map(age_vals)
# Out:
# 0         365
# 1         365
# 2         365
# 3          30
# 4           1
#          ...
# 137092     30
# 137093    365
# 137094    365
# 137095    365
# 137096    365
# Name: Age Unit, Length: 137092, dtype: int64

# %%
# Now, how can we transform the Age Value column to capture these values?
df_clean['Age Unit'] = df_clean['Age Unit'].map(age_vals)

# %%
# Sanity check
df_clean.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  Age Unit
# 0              Domestic Shorthair Mix  Brown Tabby/White           2       365
# 1             Chihuahua Shorthair Mix        White/Brown           1       365
# 2                             Raccoon               Gray           1       365
# 3  Anatol Shepherd/Labrador Retriever               Buff           4        30
# 4              Domestic Shorthair Mix       Orange Tabby           6         1

# %%
# Now, let's make a new Age in Days column!
df_clean['Age in Days'] = (df_clean['Age Number'] * df_clean['Age Unit'])

# %%
# Sanity check
df_clean.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  \
# 0              Domestic Shorthair Mix  Brown Tabby/White           2
# 1             Chihuahua Shorthair Mix        White/Brown           1
# 2                             Raccoon               Gray           1
# 3  Anatol Shepherd/Labrador Retriever               Buff           4
# 4              Domestic Shorthair Mix       Orange Tabby           6
#
#    Age Unit  Age in Days
# 0       365          730
# 1       365          365
# 2       365          365
# 3        30          120
# 4         1            6

# %%
# Now we can visualize!
df_clean['Age in Days'].plot(kind='hist');

# %%
df_clean['Age in Days'].median(), df_clean['Age in Days'].mean()
# Out:
# (365.0, 755.7718977037318)

# %%
df_clean.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  \
# 0              Domestic Shorthair Mix  Brown Tabby/White           2
# 1             Chihuahua Shorthair Mix        White/Brown           1
# 2                             Raccoon               Gray           1
# 3  Anatol Shepherd/Labrador Retriever               Buff           4
# 4              Domestic Shorthair Mix       Orange Tabby           6
#
#    Age Unit  Age in Days
# 0       365          730
# 1       365          365
# 2       365          365
# 3        30          120
# 4         1            6

# %%
df_clean['DateTime'].dt.normalize()
# Out:
# 0        2019-05-08
# 1        2018-07-18
# 2        2020-08-16
# 3        2016-02-13
# 4        2014-03-18
#             ...
# 137092   2022-01-24
# 137093   2022-02-28
# 137094   2022-02-28
# 137095   2022-02-28
# 137096   2022-02-28
# Name: DateTime, Length: 137092, dtype: datetime64[ns]

# %%
# Of course, we could also try...
# Use .dt.normalize on the DateTime column to access the date!
df_clean['Calculated Age in Days'] = (df_clean['DateTime'].dt.normalize() - df_clean['Date of Birth']).dt.days

# %%
df_clean['DateTime'].dt.normalize()
# Out:
# 0        2019-05-08
# 1        2018-07-18
# 2        2020-08-16
# 3        2016-02-13
# 4        2014-03-18
#             ...
# 137092   2022-01-24
# 137093   2022-02-28
# 137094   2022-02-28
# 137095   2022-02-28
# 137096   2022-02-28
# Name: DateTime, Length: 137092, dtype: datetime64[ns]

# %%
# Without the normalize it carries over the granular time info from one column
df_clean['DateTime'] - df_clean['Date of Birth']
# Out:
# 0         736 days 18:20:00
# 1         371 days 16:02:00
# 2         366 days 11:38:00
# 3         128 days 17:59:00
# 4           6 days 11:47:00
#                 ...
# 137092     66 days 18:20:00
# 137093    736 days 12:50:00
# 137094    664 days 13:49:00
# 137095   3058 days 13:04:00
# 137096   1165 days 14:19:00
# Length: 137092, dtype: timedelta64[ns]

# %%
# Check it
df_clean.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  \
# 0              Domestic Shorthair Mix  Brown Tabby/White           2
# 1             Chihuahua Shorthair Mix        White/Brown           1
# 2                             Raccoon               Gray           1
# 3  Anatol Shepherd/Labrador Retriever               Buff           4
# 4              Domestic Shorthair Mix       Orange Tabby           6
#
#    Age Unit  Age in Days  Calculated Age in Days
# 0       365          730                     736
# 1       365          365                     371
# 2       365          365                     366
# 3        30          120                     128
# 4         1            6                       6

# %% [markdown]
# ## Question 2: Are Most of The Animals Already Fixed?

# %% [markdown]
# Let's use `.map()` to turn the Sex upon Outcome column into a category with three values: Fixed, Intact, or Unknown.

# %%
df_clean['Sex upon Outcome'].value_counts()
# Out:
# Sex upon Outcome
# Neutered Male    48299
# Spayed Female    43578
# Intact Male      17408
# Intact Female    16904
# Unknown          10902
# Name: count, dtype: int64

# %%
df_clean.isna().sum()
# Out:
# Animal ID                     0
# Name                      40999
# DateTime                      0
# MonthYear                     0
# Date of Birth                 0
# Outcome Type                 23
# Outcome Subtype           74443
# Animal Type                   0
# Sex upon Outcome              1
# Age upon Outcome              0
# Breed                         0
# Color                         0
# Age Number                    0
# Age Unit                      0
# Age in Days                   0
# Calculated Age in Days        0
# dtype: int64

# %%
# Check out what's currently in that column
df_clean['Sex upon Outcome'].unique()
# Out:
# array(['Neutered Male', 'Unknown', 'Intact Male', 'Spayed Female',
#        'Intact Female', nan], dtype=object)

# %%
# We can write a function for this
def fixed_mapper(status):
    '''
    Takes in the current status of animals and outputs whether they have been fixed
    '''
    if status in ['Neutered Male', 'Spayed Female']:
        return 'Fixed'
    elif status in ['Intact Male', 'Intact Female']:
        return 'Intact'
    else:
        return 'Unknown'

# %%
# Now let's use it!
df_clean['Grouped Sex upon Outcome'] = df_clean['Sex upon Outcome'].map(fixed_mapper)
df_clean[['Sex upon Outcome', 'Grouped Sex upon Outcome']].head()
# Out:
#   Sex upon Outcome Grouped Sex upon Outcome
# 0    Neutered Male                    Fixed
# 1    Neutered Male                    Fixed
# 2          Unknown                  Unknown
# 3    Neutered Male                    Fixed
# 4      Intact Male                   Intact

# %%
# We had a null in that column before, did that change?
df_clean.isna().sum()
# Out:
# Animal ID                       0
# Name                        40999
# DateTime                        0
# MonthYear                       0
# Date of Birth                   0
# Outcome Type                   23
# Outcome Subtype             74443
# Animal Type                     0
# Sex upon Outcome                1
# Age upon Outcome                0
# Breed                           0
# Color                           0
# Age Number                      0
# Age Unit                        0
# Age in Days                     0
# Calculated Age in Days          0
# Grouped Sex upon Outcome        0
# dtype: int64

# %%
# Visualize it!
df_clean['Grouped Sex upon Outcome'].value_counts().plot(kind='pie');

# %%
df_clean['Grouped Sex upon Outcome'].value_counts().index
# Out:
# Index(['Fixed', 'Intact', 'Unknown'], dtype='object', name='Grouped Sex upon Outcome')

# %%
df_clean['Grouped Sex upon Outcome'].value_counts().plot(kind='bar');

# %% [markdown]
# ## A Quick Aside - for Lambda Functions!

# %% [markdown]
# Simple functions can be defined just when you need them, when you would call the function. These are called **lambda functions**. These functions are **anonymous** and disappear immediately after use.
#
# These can often be great as map transformation functions, but they can only do so much.
#
# Let's use them to fill some nulls!

# %%
simple_func = lambda x: x*x

# %%
simple_func(5)
# Out:
# 25

# %%
simple_func('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 simple_func('hello')
#
# Cell In[82], line 1, in <lambda>(x)
# ----> 1 simple_func = lambda x: x*x
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
# Check which columns still have null values
df_clean.isna().sum()
# Out:
# Animal ID                       0
# Name                        40999
# DateTime                        0
# MonthYear                       0
# Date of Birth                   0
# Outcome Type                   23
# Outcome Subtype             74443
# Animal Type                     0
# Sex upon Outcome                1
# Age upon Outcome                0
# Breed                           0
# Color                           0
# Age Number                      0
# Age Unit                        0
# Age in Days                     0
# Calculated Age in Days          0
# Grouped Sex upon Outcome        0
# dtype: int64

# %% [markdown]
# Let's look at Outcome Subtype - a lot of nulls, why do we think that is? What would be an appropriate strategy here?
#
# <br>
# <details>
#     <summary>Possible Answer</summary>
#
# - Might be that the Type doesn't have Subtypes, or that there hasn't been an outcome yet
# - Would be appropriate to fill with N/A
#
# </details>

# %%
df_clean.loc[df_clean['Outcome Subtype'].isna()]['Outcome Type'].value_counts()
# Out:
# Outcome Type
# Adoption           49866
# Return to Owner    22687
# Rto-Adopt            854
# Disposal             625
# Euthanasia           236
# Died                 113
# Relocate              25
# Missing               15
# Name: count, dtype: int64

# %%
# Let's try it!
# Note: need to use x is np.nan as our if condition
df_clean['Outcome Subtype'].map(lambda x: "N/A" if x is np.nan else x)
# Out:
# 0             N/A
# 1             N/A
# 2             N/A
# 3             N/A
# 4         Partner
#            ...
# 137092        N/A
# 137093    Partner
# 137094     Foster
# 137095     Foster
# 137096        N/A
# Name: Outcome Subtype, Length: 137092, dtype: object

# %%
# BUT! Pandas has a function for this
df_clean['Outcome Subtype'] = df_clean['Outcome Subtype'].fillna('N/A')
df_clean['Outcome Subtype']
# Out:
# 0             N/A
# 1             N/A
# 2             N/A
# 3             N/A
# 4         Partner
#            ...
# 137092        N/A
# 137093    Partner
# 137094     Foster
# 137095     Foster
# 137096        N/A
# Name: Outcome Subtype, Length: 137092, dtype: object

# %%
# We can use one of these methods to fill the nulls for Outcome Type too
# Explore the column here
df_clean['Outcome Type'].unique()
# Out:
# array(['Rto-Adopt', 'Adoption', 'Euthanasia', 'Transfer',
#        'Return to Owner', 'Died', 'Disposal', 'Missing', 'Relocate', nan],
#       dtype=object)

# %%
# Fill nulls here
df_clean['Outcome Type'] = df_clean['Outcome Type'].fillna("Unknown")

# %%
# Sanity Check
df_clean.isna().sum()
# Out:
# Animal ID                       0
# Name                        40999
# DateTime                        0
# MonthYear                       0
# Date of Birth                   0
# Outcome Type                    0
# Outcome Subtype                 0
# Animal Type                     0
# Sex upon Outcome                1
# Age upon Outcome                0
# Breed                           0
# Color                           0
# Age Number                      0
# Age Unit                        0
# Age in Days                     0
# Calculated Age in Days          0
# Grouped Sex upon Outcome        0
# dtype: int64

# %% [markdown]
# ### One More Strategy: Build a Missing Indicator
#
# While this doesn't directly answer a question we have, let's go ahead and build a new column to indicate where Name is null (just to demo).
#
# This can be quite useful when modeling, if the data being missing actually means something!

# %%
df_clean['Name'].isna()
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True
#           ...
# 137092    False
# 137093    False
# 137094    False
# 137095    False
# 137096    False
# Name: Name, Length: 137092, dtype: bool

# %%
# Quick pandas method for this
df_clean['Name Missing'] = df_clean['Name'].isna()
df_clean.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             N/A         Cat    Neutered Male          2 years
# 1             N/A         Dog    Neutered Male           1 year
# 2             N/A       Other          Unknown           1 year
# 3             N/A         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  \
# 0              Domestic Shorthair Mix  Brown Tabby/White           2
# 1             Chihuahua Shorthair Mix        White/Brown           1
# 2                             Raccoon               Gray           1
# 3  Anatol Shepherd/Labrador Retriever               Buff           4
# 4              Domestic Shorthair Mix       Orange Tabby           6
#
#    Age Unit  Age in Days  Calculated Age in Days Grouped Sex upon Outcome  \
# 0       365          730                     736                    Fixed
# 1       365          365                     371                    Fixed
# 2       365          365                     366                  Unknown
# 3        30          120                     128                    Fixed
# 4         1            6                       6                   Intact
#
#    Name Missing
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %%
df_clean[['Name', 'Name Missing']]
# Out:
#              Name  Name Missing
# 0           Chunk         False
# 1           Gizmo         False
# 2             NaN          True
# 3           Moose         False
# 4             NaN          True
# ...           ...           ...
# 137092     Rainey         False
# 137093     Noodle         False
# 137094    *Carmen         False
# 137095  Mia Marie         False
# 137096    Lucille         False
#
# [137092 rows x 2 columns]

# %% [markdown]
# Might be more interesting to build an indicator of where "Mix" is in the Breed column

# %%
df_clean['Breed'].value_counts()
# Out:
# Breed
# Domestic Shorthair Mix                   32387
# Domestic Shorthair                       10364
# Pit Bull Mix                              8937
# Labrador Retriever Mix                    7397
# Chihuahua Shorthair Mix                   6518
#                                          ...
# Chow Chow/Doberman Pinsch                    1
# Australian Shepherd/Australian Kelpie        1
# Black/Tan Hound/Great Dane                   1
# St. Bernard Smooth Coat/Mastiff              1
# Standard Schnauzer/Siberian Husky            1
# Name: count, Length: 2735, dtype: int64

# %%
df_clean['Breed'].str.contains(' Mix')
# Out:
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 137092    False
# 137093    False
# 137094     True
# 137095    False
# 137096    False
# Name: Breed, Length: 137092, dtype: bool

# %%
# Let's do it
df_clean['Mix Indicator'] = df_clean['Breed'].str.contains(' Mix')

# %%
# Sanity check
df_clean.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             N/A         Cat    Neutered Male          2 years
# 1             N/A         Dog    Neutered Male           1 year
# 2             N/A       Other          Unknown           1 year
# 3             N/A         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  \
# 0              Domestic Shorthair Mix  Brown Tabby/White           2
# 1             Chihuahua Shorthair Mix        White/Brown           1
# 2                             Raccoon               Gray           1
# 3  Anatol Shepherd/Labrador Retriever               Buff           4
# 4              Domestic Shorthair Mix       Orange Tabby           6
#
#    Age Unit  Age in Days  Calculated Age in Days Grouped Sex upon Outcome  \
# 0       365          730                     736                    Fixed
# 1       365          365                     371                    Fixed
# 2       365          365                     366                  Unknown
# 3        30          120                     128                    Fixed
# 4         1            6                       6                   Intact
#
#    Name Missing  Mix Indicator
# 0         False           True
# 1         False           True
# 2          True          False
# 3         False          False
# 4          True           True

# %%
df_clean['Mix Indicator'].sum()
# Out:
# 95782

# %% [markdown]
# ## Comparing Before and After

# %% [markdown]
# We can now see all the work we did!

# %%
# Original data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137097 entries, 0 to 137096
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         137097 non-null  object
#  1   Name              96095 non-null   object
#  2   DateTime          137097 non-null  datetime64[ns]
#  3   MonthYear         137097 non-null  object
#  4   Date of Birth     137097 non-null  datetime64[ns]
#  5   Outcome Type      137073 non-null  object
#  6   Outcome Subtype   62653 non-null   object
#  7   Animal Type       137097 non-null  object
#  8   Sex upon Outcome  137095 non-null  object
#  9   Age upon Outcome  137092 non-null  object
#  10  Breed             137097 non-null  object
#  11  Color             137097 non-null  object
#  12  Age Number        137092 non-null  object
#  13  Age Unit          137092 non-null  object
# dtypes: datetime64[ns](2), object(12)
# memory usage: 14.6+ MB

# %%
# Missing data cleaned
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 137092 entries, 0 to 137096
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Animal ID                 137092 non-null  object
#  1   Name                      96093 non-null   object
#  2   DateTime                  137092 non-null  datetime64[ns]
#  3   MonthYear                 137092 non-null  object
#  4   Date of Birth             137092 non-null  datetime64[ns]
#  5   Outcome Type              137092 non-null  object
#  6   Outcome Subtype           137092 non-null  object
#  7   Animal Type               137092 non-null  object
#  8   Sex upon Outcome          137091 non-null  object
#  9   Age upon Outcome          137092 non-null  object
#  10  Breed                     137092 non-null  object
#  11  Color                     137092 non-null  object
#  12  Age Number                137092 non-null  int64
#  13  Age Unit                  137092 non-null  int64
#  14  Age in Days               137092 non-null  int64
#  15  Calculated Age in Days    137092 non-null  int64
#  16  Grouped Sex upon Outcome  137092 non-null  object
#  17  Name Missing              137092 non-null  bool
#  18  Mix Indicator             137092 non-null  bool
# dtypes: bool(2), datetime64[ns](2), int64(4), object(11)
# memory usage: 23.1+ MB

# %% [markdown]
# # Level Up: `.applymap()`

# %% [markdown]
# `.applymap()` is used to apply a transformation to each element of a DataFrame.

# %%
# This line will apply the base `type()` function to 
# all entries of the DataFrame.

df.applymap(type).head()
# Out:
# /var/folders/0c/wkrr_xjn2xz65fx41rj45h6w0000gp/T/ipykernel_4654/4037118714.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(type).head()
#        Animal ID             Name  \
# 0  <class 'str'>    <class 'str'>
# 1  <class 'str'>    <class 'str'>
# 2  <class 'str'>  <class 'float'>
# 3  <class 'str'>    <class 'str'>
# 4  <class 'str'>  <class 'float'>
#
#                                             DateTime      MonthYear  \
# 0  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 1  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 2  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 3  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 4  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
#
#                                        Date of Birth   Outcome Type  \
# 0  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 1  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 2  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 3  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 4  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
#
#    Outcome Subtype    Animal Type Sex upon Outcome Age upon Outcome  \
# 0  <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 1  <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 2  <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 3  <class 'float'>  <class 'str'>    <class 'str'>    <class 'str'>
# 4    <class 'str'>  <class 'str'>    <class 'str'>    <class 'str'>
#
#            Breed          Color     Age Number       Age Unit
# 0  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 1  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 2  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 3  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 4  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>

# %% [markdown]
# # Level Up: Faster NumPy Methods

# %% [markdown]
# In general, `np.where()` and `np.select()` are faster than `map()`. This won't matter too much with reasonably-sized data but can be a consideration for ***big data***.

# %%
# Let's copy the dataframe to play around with
level_up = df_clean.copy()

# %%
level_up.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             N/A         Cat    Neutered Male          2 years
# 1             N/A         Dog    Neutered Male           1 year
# 2             N/A       Other          Unknown           1 year
# 3             N/A         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  \
# 0              Domestic Shorthair Mix  Brown Tabby/White           2
# 1             Chihuahua Shorthair Mix        White/Brown           1
# 2                             Raccoon               Gray           1
# 3  Anatol Shepherd/Labrador Retriever               Buff           4
# 4              Domestic Shorthair Mix       Orange Tabby           6
#
#    Age Unit  Age in Days  Calculated Age in Days Grouped Sex upon Outcome  \
# 0       365          730                     736                    Fixed
# 1       365          365                     371                    Fixed
# 2       365          365                     366                  Unknown
# 3        30          120                     128                    Fixed
# 4         1            6                       6                   Intact
#
#    Name Missing  Mix Indicator
# 0         False           True
# 1         False           True
# 2          True          False
# 3         False          False
# 4          True           True

# %%
level_up.values
# Out:
# array([['A794011', 'Chunk', Timestamp('2019-05-08 18:20:00'), ...,
#         'Fixed', False, True],
#        ['A776359', 'Gizmo', Timestamp('2018-07-18 16:02:00'), ...,
#         'Fixed', False, True],
#        ['A821648', nan, Timestamp('2020-08-16 11:38:00'), ..., 'Unknown',
#         True, False],
#        ...,
#        ['A845839', '*Carmen', Timestamp('2022-02-28 13:49:00'), ...,
#         'Fixed', False, True],
#        ['A844321', 'Mia Marie', Timestamp('2022-02-28 13:04:00'), ...,
#         'Fixed', False, False],
#        ['A813933', 'Lucille', Timestamp('2022-02-28 14:19:00'), ...,
#         'Fixed', False, False]], dtype=object)

# %% [markdown]
# ## NumPy's `where()` Method

# %%
# First pass a condition
level_up['Adopted1'] = np.where(level_up['Outcome Type'] == 'Adoption',
                                True,  # What to fill with if the condition is true
                                False)  # What to fill with if not true
level_up.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             N/A         Cat    Neutered Male          2 years
# 1             N/A         Dog    Neutered Male           1 year
# 2             N/A       Other          Unknown           1 year
# 3             N/A         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Age Number  \
# 0              Domestic Shorthair Mix  Brown Tabby/White           2
# 1             Chihuahua Shorthair Mix        White/Brown           1
# 2                             Raccoon               Gray           1
# 3  Anatol Shepherd/Labrador Retriever               Buff           4
# 4              Domestic Shorthair Mix       Orange Tabby           6
#
#    Age Unit  Age in Days  Calculated Age in Days Grouped Sex upon Outcome  \
# 0       365          730                     736                    Fixed
# 1       365          365                     371                    Fixed
# 2       365          365                     366                  Unknown
# 3        30          120                     128                    Fixed
# 4         1            6                       6                   Intact
#
#    Name Missing  Mix Indicator  Adopted1
# 0         False           True     False
# 1         False           True      True
# 2          True          False     False
# 3         False          False      True
# 4          True           True     False

# %%
level_up['Adopted2'] = level_up['Outcome Type'].map(lambda x: True if x == 'Adoption' else False)
level_up.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  ...  \
# 0             N/A         Cat    Neutered Male          2 years  ...
# 1             N/A         Dog    Neutered Male           1 year  ...
# 2             N/A       Other          Unknown           1 year  ...
# 3             N/A         Dog    Neutered Male         4 months  ...
# 4         Partner         Cat      Intact Male           6 days  ...
#
#                Color Age Number  Age Unit  Age in Days  \
# 0  Brown Tabby/White          2       365          730
# 1        White/Brown          1       365          365
# 2               Gray          1       365          365
# 3               Buff          4        30          120
# 4       Orange Tabby          6         1            6
#
#    Calculated Age in Days  Grouped Sex upon Outcome Name Missing  \
# 0                     736                     Fixed        False
# 1                     371                     Fixed        False
# 2                     366                   Unknown         True
# 3                     128                     Fixed        False
# 4                       6                    Intact         True
#
#    Mix Indicator  Adopted1  Adopted2
# 0           True     False     False
# 1           True      True      True
# 2          False     False     False
# 3          False      True      True
# 4           True     False     False
#
# [5 rows x 21 columns]

# %%
# Let's time how long it takes np.where() to run by running it multiple times
# %timeit np.where(level_up['Outcome Type'] == 'Adoption', True, False)
# Out:
# 6.44 ms ± 586 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Let's time how long it takes .map() to run by running it multiple times
# %timeit level_up['Outcome Type'].map(lambda x: True if x == 'Adoption' else False)
# Out:
# 16 ms ± 1.01 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## NumPy's `select()` Method

# %%
# We can write a function for this
def fixed_mapper(status):
    '''
    Takes in the current status of animals and outputs whether they have been fixed
    '''
    if status in ['Neutered Male', 'Spayed Female']:
        return 'Fixed'
    elif status in ['Intact Male', 'Intact Female']:
        return 'Intact'
    else:
        return 'Unknown'

# %% [markdown]
# Again, `numpy` will be faster:

# %%
# Define our list of conditions
conditions = [level_up['Sex upon Outcome'] == 'Neutered Male',
              level_up['Sex upon Outcome'] == 'Spayed Female',
              level_up['Sex upon Outcome'] == 'Intact Male',
              level_up['Sex upon Outcome'] == 'Intact Female',
              level_up['Sex upon Outcome'] == 'Unknown',
              level_up['Sex upon Outcome'].isna()]

# Define a matching list of outcomes
choices = ['Fixed', 'Fixed', 'Intact', 'Intact', 'Unknown', 'Unknown']

# %%
# Use np.select
level_up['Grouped Sex upon Outcome1'] = np.select(conditions, choices)
level_up['Grouped Sex upon Outcome1']
# Out:
# 0           Fixed
# 1           Fixed
# 2         Unknown
# 3           Fixed
# 4          Intact
#            ...
# 137092     Intact
# 137093      Fixed
# 137094      Fixed
# 137095      Fixed
# 137096      Fixed
# Name: Grouped Sex upon Outcome1, Length: 137092, dtype: object

# %%
# Check we got the same results with np.where()
(level_up['Grouped Sex upon Outcome1'] != level_up['Grouped Sex upon Outcome']).sum()
# Out:
# 0

# %%
# Let's time how long it takes .map() to run by running it multiple times
# %timeit level_up['Sex upon Outcome'].map(fixed_mapper)
# Out:
# 16.5 ms ± 1.15 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Let's time how long it takes np.select() to run by running it multiple times
# %timeit np.select(conditions, choices)
# Out:
# 4.42 ms ± 306 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
level_up.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  ...  \
# 0             N/A         Cat    Neutered Male          2 years  ...
# 1             N/A         Dog    Neutered Male           1 year  ...
# 2             N/A       Other          Unknown           1 year  ...
# 3             N/A         Dog    Neutered Male         4 months  ...
# 4         Partner         Cat      Intact Male           6 days  ...
#
#   Age Number Age Unit  Age in Days  Calculated Age in Days  \
# 0          2      365          730                     736
# 1          1      365          365                     371
# 2          1      365          365                     366
# 3          4       30          120                     128
# 4          6        1            6                       6
#
#    Grouped Sex upon Outcome  Name Missing Mix Indicator  Adopted1  Adopted2  \
# 0                     Fixed         False          True     False     False
# 1                     Fixed         False          True      True      True
# 2                   Unknown          True         False     False     False
# 3                     Fixed         False         False      True      True
# 4                    Intact          True          True     False     False
#
#    Grouped Sex upon Outcome1
# 0                      Fixed
# 1                      Fixed
# 2                    Unknown
# 3                      Fixed
# 4                     Intact
#
# [5 rows x 22 columns]
