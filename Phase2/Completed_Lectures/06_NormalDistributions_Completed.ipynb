# %% [markdown]
# # Objectives

# %% [markdown]
# * Describe the normal distribution's Empirical Rule
# * Calculate $z$-scores from a normal distribution through standardization
# * Define the Central Limit Theorem

# %%
# Imports!
from scipy import stats

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import pandas as pd
import numpy as np

# %% [markdown]
# # Normal Distribution

# %% [markdown]
# We'll find that the **normal distribution** or **normal curve** or **bell curve** (it has many names) is a very common distribution and it's very useful to us in statistics.

# %% [markdown]
# ![](images/normal_curve_animation.gif)

# %% [markdown]
# ## Why a Normal Distribution?

# %% [markdown]
# Turns out the normal distribution describes many phenomena. Think of anything that has a typical range:
#
# - human body temperatures
# - sizes of elephants
# - sizes of stars
# - populations of cities
# - IQ
# - heart rate

# %% [markdown]
# Among human beings, 98.6 degrees Fahrenheit is an _average_ body temperature. Many folks' temperatures won't measure _exactly_ 98.6 degrees, but most measurements will be _close_. It is much more common to have a body temperature close to 98.6 (whether slightly more or slightly less) than it is to have a body temperature far from 98.6 (whether significantly more or significantly less). This is a hallmark of a normally distributed variable.

# %%
# Visualize it
fig, ax = plt.subplots()

mu = 0
sigma = 1
# This defines the points along the x-axis
x = np.linspace(
        stats.norm(mu,sigma).ppf(0.01), # Start plotting here
        stats.norm(mu,sigma).ppf(0.99), # End plotting here
        100                             # Number of points
)
# The values as at x given by the normal curve (with mu & sigma)
y = stats.norm(mu,sigma).pdf(x)
ax.plot(x, y,'r-');

# %% [markdown]
# The Standard Normal Distribution, also known as a Gaussian distribution, is special not only because it shows up EVERYWHERE but also because it's symmetric (mean == median == mode)

# %% [markdown]
# ### Normal Curve
#
# If you're curious about how we can mathematically define a normal curve, we give this below. (Don't worry, you don't need to recall the mathematical definition).
#
# <details>
#
# $\Large f(x) = \frac{1}{\sqrt{2\pi\sigma^2}}e^{\frac{-(x - \mu)^2}{2\sigma^2}}$
#
# This might look complicated at first, but it means that the we describe a normal curve with just **two parameters**: $\sigma^2$ (the variance) & $\mu$ (the mean). You may see the notation $N(\mu, \sigma^2)$ which emphasizes there are only two parameters to describe the distribution.
# </details>

# %% [markdown]
# ## *Standard* Normal Distribution

# %% [markdown]
# A special normal distribution called the **standard normal distribution** has a mean of 0 and variance of 1. This is also known as a **z distribution**.

# %% [markdown]
# Since we know that the shape of a normal distribution changes based on its mean and variance, we'll typically convert or **standardize** our normal distribution to the standard normal distribution.

# %% [markdown]
# We simply subtract the mean $\mu$ from each value and then divide by the standard deviation $\sigma$:
#
# $$\frac{x - \mu}{\sigma}$$
#
# We call this process **standardization**.

# %% [markdown]
# ![norm_to_z](images/norm_to_z.png)

# %%
# Let's transform the normal distribution centered on 5
# with a standard deviation of 2 into a standard normal

# Generating our data
# stats.norm.rvs()
normal_dist = np.random.normal(loc=5, scale=2, size=1000)

np.mean(normal_dist)
# Out:
# 4.923046128605585

# %%
normal_dist
# Out:
# array([ 0.43764167,  5.03123059,  5.32604079,  2.73724382,  5.54230238,
#         3.93069942,  0.1842949 ,  9.64295543,  4.8185249 ,  1.60908933,
#         3.9474853 ,  4.30939385,  6.68365633,  7.88995605,  2.33343444,
#         6.54864714,  4.54738077,  3.10415044,  4.89463476,  7.46843925,
#         6.24908848,  4.56582629,  6.00784009,  4.97527936,  5.38001742,
#         6.06474776,  3.70245024,  7.20366406,  4.03359712,  6.05761111,
#         2.75822209,  7.1359149 ,  3.78971754,  6.97850242,  6.6170722 ,
#         3.53071211,  5.12083857,  5.11605077,  7.78743232,  8.84450512,
#         5.4911078 ,  5.20155877,  7.36172815,  6.72222125,  2.30446616,
#         2.26224007,  3.45428308,  7.14627639,  6.74161418,  0.41289786,
#         6.19601292,  6.01957576,  5.57804863,  4.43544596,  8.12308782,
#         5.01671609,  4.20354326,  0.84494845,  3.42291222,  6.59499488,
#         4.96046071,  7.5146408 ,  6.59005327,  8.90048192,  3.32699431,
#         7.77907346,  3.31551444,  4.97256462,  4.14719584,  4.44526368,
#         9.03295781,  6.24439869,  5.16830622,  8.24566295,  5.97455802,
#         7.31153068,  2.61317342,  6.3805954 ,  6.07177848,  1.7119095 ,
#         1.82641843,  3.33214884,  5.17617047,  7.97319511,  4.96811303,
#         5.60009291,  4.60562948,  4.16989599,  5.53358994,  6.06241407,
#         4.28498057,  3.92112096,  8.64033183,  6.05198324,  6.02853761,
#         3.43478195,  3.28116245,  5.85443829,  5.86726058,  6.14123937,
#         2.56873126,  8.809989  ,  7.40224456,  2.39451081,  5.06141375,
#         5.6736944 ,  5.13507367,  8.1823535 ,  4.13851325,  7.19652753,
#         3.86860423,  7.19692038,  8.060938  ,  4.8255032 ,  6.45776282,
#         3.36349801,  5.06026843,  4.36920512,  4.6967962 ,  6.1960018 ,
#         7.31962202,  6.27346932,  6.41549299,  4.50959761,  1.94291378,
#         4.27161134,  5.19092815,  4.50759511,  9.47238087,  1.31632208,
#         7.70646592,  6.56217631,  4.92396719,  1.78757102,  3.87315733,
#         4.39162977,  1.77258325,  4.54883581,  5.38383664,  2.35250583,
#         4.00547166,  8.24000071,  5.56114255,  5.48314986,  6.56972171,
#         7.29009438,  5.0239095 ,  6.3212504 ,  7.26026168,  4.97231705,
#         1.83738565,  4.52641721,  8.54305048,  6.83937722,  7.65219992,
#         7.91623209,  3.80931903,  4.72359279,  3.70571521,  5.82869565,
#         5.46595825,  7.15386787,  1.83788461,  7.36916886,  1.85645084,
#         0.93376945,  3.59957221,  7.01240096,  4.25643818,  7.35855285,
#         3.27554801,  6.06965418,  9.06417442,  1.75503417,  6.97981454,
#         5.39423977,  2.02215088,  7.94632547,  5.48144626,  4.89969675,
#         6.05809674,  4.06531486,  5.41554633,  3.66407154,  5.37796577,
#         6.43678616,  8.78862906,  6.82030204,  5.34181982,  5.46284155,
#         1.35704411,  8.12673474,  4.78599191,  3.89735172,  4.33798303,
#         5.48919771,  5.11437814,  5.61374465,  8.42629185,  4.17702118,
#         3.13059685,  5.25876598,  5.26244337,  3.89899116,  3.87480253,
#         3.24202641,  4.02519232,  5.71957752,  5.49561546,  4.35016407,
#         3.70448081,  5.76926736,  5.29180655,  4.16952317,  3.68374467,
#         7.00729268,  2.4647613 ,  5.94695838,  2.47780063,  6.41948894,
#         6.06945101,  4.26849909,  4.41351751,  5.10265831,  2.8658435 ,
#         4.25936886,  3.74628674,  1.31528007,  8.27984318,  5.85160929,
#         5.15113871,  4.51469324,  3.0237758 ,  2.39102223,  4.63038427,
#         4.61127178,  4.15506574,  7.42050028,  7.5250435 ,  5.14621925,
#         4.6087511 ,  3.9470618 ,  3.70389453,  2.25301205,  7.83225719,
#         8.69018846,  6.10084322,  3.44063051,  5.09046408,  3.1313992 ,
#         4.36218578,  4.05879226,  3.04627199,  4.66795233,  6.60012754,
#         6.10093455,  7.56641759,  6.50124776,  5.25752946,  6.33025376,
#         4.31067042,  4.52542291,  5.98077754,  2.33906965,  5.36077354,
#         6.40381539,  6.48678663,  5.04669805,  7.31992156,  3.04528851,
#         2.88637475,  2.54483335,  8.14918938,  4.94084343,  3.4256729 ,
#         6.57913595,  7.58680962,  4.9825105 ,  1.03219357,  4.19064092,
#         3.9663771 ,  5.23069918,  4.09284916,  2.7270515 ,  5.12732946,
#         4.509361  ,  6.67747783,  4.9946682 ,  7.49916137,  8.79473113,
#         8.43037272,  5.51902854,  3.04999765,  6.26890363,  2.71535914,
#         2.89843815,  7.18983256,  5.91180146,  3.55238254,  5.76115226,
#         7.12979233,  4.43518794,  6.10227419,  1.9584528 ,  6.36129011,
#         6.84032442,  2.28632502,  6.96635786,  6.26669686,  3.95767312,
#         3.5648607 ,  3.11542178,  4.39701784,  5.81200888,  2.81107965,
#         3.20859311,  3.55314141,  2.9006476 ,  4.38714767,  7.56275352,
#         6.73466404,  6.12784359,  7.05645378,  4.18427166,  4.00244715,
#         4.85926798,  0.75439719,  7.39801987,  5.39809458,  6.44200949,
#         5.0971106 ,  4.32037733,  5.48697396,  3.98256706,  2.20641436,
#         6.62813483,  4.94850414,  4.9258439 ,  7.97157758,  7.14822727,
#         6.45183464,  4.23624484,  6.73439574,  8.1826802 ,  6.37094583,
#         5.46098142,  0.67568782,  1.86577906,  3.55444215,  5.16502423,
#         0.87563123,  6.17530561,  3.5656497 ,  3.02525945,  6.02127212,
#         8.01904749,  8.30237479,  5.05975419,  6.44141186,  4.16963531,
#         6.12448802,  5.29662493,  5.26530573,  4.23923682,  3.15757124,
#         4.10331124,  2.96964033,  5.26774916,  5.90378015,  8.92320744,
#         6.1341567 ,  2.31989226,  8.01221175,  5.34160348,  2.82117873,
#         2.66964457,  3.81440625,  4.10019007,  4.86553071,  5.25958705,
#         4.50217688,  8.97938554,  4.2366507 ,  5.12215623,  6.02020569,
#         5.29949108,  3.3172635 ,  6.43507345,  3.88195131,  5.68216027,
#         1.68933425,  5.38521716,  1.17957762,  7.83992618,  3.18107992,
#         1.11360715,  3.4814652 ,  3.94075192,  4.86453807,  4.71008555,
#         7.53603042,  7.71153246,  4.48313261,  3.73047613,  6.39854121,
#         3.14770306,  5.53520812,  4.47759882,  8.16689265,  1.6667507 ,
#         4.63473375,  6.24747899,  7.55468665,  5.75001072,  3.69589277,
#         2.0628957 ,  5.36428816,  4.69832603,  3.45313562,  7.01018583,
#         5.41754928,  4.21139212,  6.02997934,  1.80020341,  4.95925126,
#         4.07465666,  3.59524516,  6.25171312,  2.49141801,  4.57494793,
#         7.22805357,  3.91703174,  2.60779426,  3.21945058,  6.66032669,
#         3.76684446,  4.16801926,  3.24298073,  4.16461234,  2.96353211,
#         1.48477666,  4.35248163,  2.90135232,  4.63847031,  5.31386806,
#         3.14690728,  5.57607213,  1.38579489, -0.34650436,  0.78620016,
#         4.5696145 ,  7.19808474,  5.94072026,  5.24168142,  6.41012541,
#         4.98062275,  2.76536015,  3.54733086,  4.91009853,  4.88867352,
#         3.11564369,  6.0426219 ,  3.96206385,  5.43222982,  2.42221541,
#         3.22306874,  2.18213958,  8.6370555 ,  5.48938451,  4.43474793,
#         5.36025932,  7.86708532,  3.50202638,  2.12584958,  4.52802533,
#         7.35316424,  3.6155218 ,  4.06639136,  5.5702778 ,  3.20965019,
#         5.19359253,  7.44097744,  8.28203753,  5.51791187,  5.27885686,
#         4.54879512,  6.23717186,  5.65996226,  3.04259162,  9.60717046,
#         7.39803244,  5.09089817,  4.46456108,  6.22385152,  2.48807016,
#         8.71071043,  4.64075264,  7.17198285,  6.06304   ,  5.8354021 ,
#         4.48842456,  8.25717657,  8.4856809 ,  4.12106074,  2.84166208,
#         3.3949963 ,  5.66372146,  4.984061  ,  6.98250418,  1.73902036,
#         3.99390373,  5.95501358,  2.07008825,  5.39630931,  6.36986655,
#         4.28117044,  2.26813431,  5.10985137,  5.45378697,  8.51092726,
#         2.63954652,  4.13250033,  8.27826282,  3.94285898,  7.81033975,
#         7.03184419,  6.0402246 ,  4.34861819,  7.22025503,  6.35366885,
#         6.99274847,  4.47432446,  5.70473937, -1.98271646,  6.97111052,
#         6.48329991,  7.98396235,  3.47670986,  3.96778492,  5.04157781,
#         6.28389638,  4.93797423,  2.65427811,  6.26352501,  8.48550206,
#         5.06135567,  3.16356601,  5.99196429,  8.22352217,  3.86685942,
#         6.30709988,  3.82781004,  0.47975745,  3.84190902,  5.35226826,
#         7.47700732,  4.25790087,  2.30084132,  3.55835266,  8.84953184,
#         5.84839608,  3.3394435 ,  6.74013688,  7.09579573,  5.78263243,
#         3.67356275,  6.01304938,  4.23334688,  1.47755502,  4.9808462 ,
#         6.7627056 ,  5.82207366,  8.56532074,  3.68147925,  7.48779283,
#         1.18374255,  5.78384922,  4.63617431,  3.70663983,  7.41968806,
#         3.84255229,  2.9574075 ,  6.83986284,  4.83428302,  2.4606561 ,
#         0.83440155,  5.00033637,  6.35757913,  4.11812933,  1.42055764,
#         5.97736747,  6.56523179,  2.20593606,  1.20038082,  7.16196663,
#         5.18937809,  6.35690841,  6.12128524,  3.34228357,  2.91110444,
#         5.18513113,  2.51704469,  5.66879954,  5.69481997,  4.50064302,
#         8.13983212,  5.22171364,  2.85508053,  6.74944033,  6.5556949 ,
#         6.48264713,  5.86074158,  5.82275434,  3.37523942,  6.4732827 ,
#         3.43993802, 11.094455  ,  5.71115874,  6.26958154,  2.28936871,
#         7.67558385,  6.72542263,  8.27683848,  3.9399097 ,  6.22392994,
#         5.21602103,  3.7504481 ,  7.4062688 ,  2.60784762,  3.37776575,
#        -0.44200796,  0.40358294,  5.63684162,  8.96476511,  9.2158144 ,
#         5.86994   ,  7.77012695,  8.63652982,  1.01937118,  0.40263066,
#         7.4873129 ,  5.08481796,  3.45995691,  2.98349121,  3.60248823,
#         2.66373281,  0.83246506,  0.80246297,  5.96933144,  1.7284812 ,
#         4.71008957,  1.79007732,  3.13891567,  5.3679995 ,  3.89028198,
#         2.40030797,  2.28662369,  2.33406339,  6.51385368,  6.1401414 ,
#         6.14406039,  8.32494411,  4.01137315,  6.24658067,  3.98236577,
#         5.26530009,  7.1193491 ,  4.44767227,  4.12291567,  5.10452196,
#         6.00099929,  5.56250806,  6.95482159,  8.57984333,  6.11181827,
#         4.82728117,  5.02877306,  6.50586042,  6.00370861,  3.05058023,
#         4.30404692,  1.61751233,  3.84461964,  2.21163898,  9.04582827,
#        -0.6096266 ,  4.53430967,  4.38081905,  3.94635879,  5.18334162,
#         5.80080099,  4.79196352,  6.96794538,  3.28955508,  4.01464615,
#         4.08143313,  4.3072762 ,  3.64735776,  7.41776165,  3.22475438,
#         4.01615962,  4.12239002,  2.26575689,  4.78713364,  4.82301971,
#         2.31735992,  5.68071522,  6.83208958,  4.73868   ,  0.80575647,
#         3.67100002,  9.64655669,  3.57477161,  2.39586133,  4.77420066,
#         6.20782933,  3.39434133,  3.21464902,  6.31803893,  5.55076535,
#         4.94073248, 10.45335085,  4.14123392,  3.5700988 ,  5.5077861 ,
#         4.93954017,  2.12085157,  6.10297485,  6.8885683 ,  3.80294375,
#         2.25969023,  2.24996939,  8.65957371,  2.92882254,  5.31267152,
#         7.29794458,  6.28676279,  6.07041238,  4.72412929,  7.64603886,
#         5.18356037,  3.17794103,  5.95793736,  5.05772539,  6.44618034,
#         1.42429412,  6.09043925,  2.97551883,  7.1825996 ,  4.63711201,
#         7.36271212,  2.56039789, -0.0479424 ,  5.84132257,  5.1780519 ,
#         5.4806027 ,  6.44271867,  7.70857655,  7.79915868,  1.65277118,
#         5.52661465,  4.16951371,  6.4276794 ,  4.22909628,  8.39911025,
#         1.02847758,  5.72593957,  4.1322861 ,  3.29631914,  2.42194924,
#         4.60363822,  3.06508656,  1.90571346,  3.88446636,  5.510925  ,
#         3.16100545,  6.83860467,  8.58227343,  4.09977359,  4.08909275,
#         4.97380225,  6.29926938,  6.72221282,  2.36994235,  2.44311789,
#         5.00846872,  3.46231936,  5.56832275,  8.22868295,  6.06191116,
#         4.82909977,  6.20837059,  4.07500985,  2.62318246,  7.08723898,
#         4.24053103,  6.78710607,  6.48225866,  6.40940746,  3.87708204,
#         5.11303245,  7.12238872,  3.07167104,  6.39353975,  3.62563963,
#         1.81552894,  6.41536678,  4.00772058,  6.026005  ,  4.10507319,
#         7.43856498,  4.84308412,  4.98439365,  4.14204661,  6.55942613,
#         1.80236892,  5.7782673 ,  1.64959197,  5.16113086,  6.70198471,
#         4.51592365,  8.01778122,  5.96783573,  4.68426847,  7.39664391,
#         5.02477795,  3.38042572,  5.18824973,  7.10883665,  6.28488303,
#         6.59750476,  3.01794911,  4.64957857,  7.99204048,  3.65181917,
#         6.95593046,  3.3828372 ,  5.63233676,  8.09368658,  4.88786382,
#         5.25210781,  3.0177217 ,  5.29450315,  5.29819982,  3.44481514,
#         2.08361005,  5.00728197,  3.16697369,  2.31939733,  4.84300336,
#         4.37602963,  2.4408435 ,  1.95978723,  5.99353893,  5.74819885,
#         3.70849764,  4.8289218 ,  7.29482383,  4.28058371,  3.38113055,
#         6.21389592,  2.56726281,  4.61761448,  4.78013281,  1.90228102,
#         3.85244332,  1.28612316,  2.99904235,  5.8705685 ,  2.03233972,
#         5.72956204,  7.34622   ,  6.51496501,  6.72052626,  4.3678358 ,
#         4.73007896,  5.88475326,  6.8014702 ,  5.03456845,  7.01771794,
#         5.85675821,  5.19218442,  4.39724219,  0.80669649,  4.13329637,
#         6.56211163,  3.29995788,  5.39572895,  5.12207452,  7.01017677,
#        -0.56532731,  6.13636476,  3.92006194,  5.39948136,  2.99159461,
#         7.34694238,  5.18044813,  4.91114899,  3.44326542,  7.68851151,
#         1.9028709 ,  1.87165718,  3.65174488,  5.2159366 ,  3.72150303,
#         6.25480963,  7.29368231,  7.35279705,  5.9685853 ,  5.1206301 ,
#         2.13101892,  7.78577252,  4.11022337,  1.32164958,  4.43973767,
#         5.0590012 ,  4.4848469 ,  5.16749775,  1.78987948,  5.88164727,
#         3.02632658,  6.18936843,  4.95418868,  8.39380351,  4.32758063,
#         5.22022953,  6.38660016,  0.79013305,  5.87831618,  6.12447444,
#         6.72883103,  5.96585538,  7.34902823,  7.01773847,  5.13071231,
#         5.75367822,  7.37771793,  4.43140772,  2.77823633,  4.69453753,
#         3.41269207,  1.35487486,  5.28642396,  4.36917712,  5.10623779,
#         2.4600617 ,  2.67353522,  3.36077092,  5.17410679,  3.98736371,
#        11.6705436 ,  9.10671099,  2.10099268,  1.38208779,  6.22517038,
#         1.59850301,  2.4746776 ,  2.78332476,  2.41329639,  2.17687562,
#         3.61852781,  6.93051043,  5.74347354,  3.15672728,  1.81716981,
#         3.06078394,  5.35441663,  3.75698762,  1.03813848,  4.98864483,
#         3.38451984,  5.89468375,  8.09411523,  1.43615923,  3.79019079,
#         5.1693709 ,  3.77688049,  5.21529158,  2.6360848 ,  5.01229037,
#         4.94180261,  5.93443598,  8.82204709,  3.46299407,  5.58603559,
#         2.12184836,  1.83385399, 11.85445539,  3.21901731,  6.48389262,
#         5.85764417,  5.17193726,  8.43465537,  2.47215735,  0.33698285,
#         3.56179382,  2.66371054,  7.12513614,  5.14307346,  5.53006567])

# %%
# Here, let's standardize by hand
# (x - mean) / std
z_dist = [(x - np.mean(normal_dist)) / np.std(normal_dist)
          for x in normal_dist]

np.mean(z_dist)
# Out:
# 1.9895196601282806e-16

# %%
# Visualize it
fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(10, 6))

sns.histplot(data=normal_dist, ax=ax0)
ax0.set_title('Before Standardization')

sns.histplot(data=z_dist, ax=ax1)
ax1.set_title('After Standardization')

plt.tight_layout()

# %% [markdown]
# Talking about the **standard normal distribution** can be very convenient since the values correspond to the number of standard deviations above or below the mean.

# %% [markdown]
# ## $z$-Score

# %% [markdown]
# A **$z$-score** for a specific data point $x$ (in a normal distribution) is simply the distance to the mean in the units of standard deviations
#
# $$\large z = \frac{x - \mu}{\sigma}$$
#
# By calculating the z-score of an individual point, we can see how unlikely a value is.

# %% [markdown]
# Here's a little site with some [interactive Gaussians](https://www.intmath.com/counting-probability/normal-distribution-graph-interactive.php)

# %% [markdown]
# #### 🧠 Knowledge Check

# %% [markdown]
# What would the $z$-score be for the middle of a normal curve?
#
# - 0

# %% [markdown]
# ### The Empirical Rule

# %% [markdown]
# > Rule states that $68\%$ of the values of a normal distribution of data lie within 1 standard deviation ($\sigma$) of the mean, $95\%$ within $2\sigma$, and $99.7\%$ within $3\sigma$.
#
# This makes it really quick to look at a normal distribution and understand where values tend to lie

# %% [markdown]
# <img src='https://github.com/learn-co-students/dsc-0-09-12-gaussian-distributions-online-ds-ft-031119/blob/master/normalsd.jpg?raw=true' width=700/>

# %% [markdown]
# #### 🧠 Knowledge Check

# %% [markdown]
# About what percentage of the values would be between a $z$-score of $-1$ and a $z$-score of $2$?
#
# <details>
#     <summary>Answer</summary>
#     About $82\%$
# </details>

# %%
34 + 34 + 13.5
# Out:
# 81.5

# %% [markdown]
# # Exercises

# %% [markdown]
# The distribution of people's heights in the United States has a **mean of 66 inches** and a **standard deviation of 4 inches**.

# %% [markdown]
# ## Height $z$-score

# %% [markdown]
# Calculate the z-score of a height of **76 inches.**

# %%
# Your code here
(76 - 66) / 4
# Out:
# 2.5

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#     <code># z-score: z = (x - mu) / std
# (76 - 66) / 4</code>
# </details>

# %% [markdown]
# #### Describe the z-score - what does it tell us?

# %%
1 - stats.norm(loc=0, scale=1).cdf(2.5)
# Out:
# 0.006209665325776159

# %%
stats.norm(loc=66, scale=4).sf(76)
# Out:
# 0.006209665325776134

# %%
stats.norm.sf(2.5, loc=0, scale=1)
# Out:
# 0.006209665325776134

# %% [markdown]
# ## Height Empirical Rule

# %% [markdown]
# Determine the proportion of those whose height is between **62 inches and 74 inches**.

# %%
# Your code here

# %% [markdown]
# <details>
#     <summary>Answer 1</summary>
# <code># z-scores for 62" and 74":
# z_62 = (62 - 66) / 4
# z_74 = (74 - 66) / 4
# z_62, z_74</code>
#     </details>

# %% [markdown]
# <details>
#     <summary>Answer 2</summary>
#     <code>heights = stats.norm(loc=66, scale=4)
# heights.cdf(74) - heights.cdf(62)</code>
#     </details>

# %% [markdown]
# ## Height Percentile

# %% [markdown]
# Assuming the above distribution of people's heights in the United States is approximately normal, what percent of people have a height **less than 75 inches**?

# %%
# Your code here
stats.norm(loc=66, scale=4).cdf(75)
# Out:
# 0.9877755273449553

# %%
1 - stats.norm(loc=66, scale=4).sf(75)
# Out:
# 0.9877755273449553

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#     <code>heights.cdf(75)</code>
#     </details>

# %% [markdown]
# ## Bonus

# %% [markdown]
# Assuming the above distribution of people's heights in the United States is approximately normal, what range of heights contain the **middle 50% of values**, also known as the _interquartile range_ (IQR)?

# %%
# norm_dist
n_dist = stats.norm(loc=66, scale=4)

# %%
# Code
n_dist.ppf(.25), n_dist.ppf(.75)
# Out:
# (63.30204099921567, 68.69795900078432)

# %%
n_dist.cdf(68.7) - n_dist.cdf(63.3)
# Out:
# 0.5003242350564465

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#     <code>heights.ppf(0.25), heights.ppf(0.75)</code>
#     </details>

# %% [markdown]
# ## Time for Pandas!
#
# Let's use the same Seattle City Employee data from the first Distributions lecture to check out what scaling looks like in practice!
#
# Data source: https://data.seattle.gov/City-Business/City-of-Seattle-Wage-Data/2khk-5ukd

# %%
# Read in the data
df = pd.read_csv('data/City_of_Seattle_Wage_Data_031422.csv')

# %%
# Check it
df.head()
# Out:
#                     Department    Last Name First Name             Job Title  \
# 0     Seattle Public Utilities    Batchelor      Craig  Civil Engrng Spec,Sr
# 1     Finance & Admin Services       Altice    Jeffrey         Auto Mechanic
# 2     Finance & Admin Services       Montes    Valeria          Cust Svc Rep
# 3              Fire Department       Kuklok    Rebecca        Cust Svc Rep *
# 4  Planning & Comm Development  Quirindongo       Rico            Executive3
#
#    Hourly Rate
# 0        53.740
# 1        39.780
# 2        29.450
# 3        29.450
# 4        97.164

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11739 entries, 0 to 11738
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Department    11739 non-null  object
#  1   Last Name     11739 non-null  object
#  2   First Name    11739 non-null  object
#  3   Job Title     11739 non-null  object
#  4   Hourly Rate   11739 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 458.7+ KB

# %%
# Rename the columns
df = df.rename(columns = lambda x: x.replace(" ", ""))

# %%
# Describe the numeric column
df.describe()
# Out:
#          HourlyRate
# count  11739.000000
# mean      47.817331
# std       16.722128
# min        5.530000
# 25%       35.400000
# 50%       47.340000
# 75%       59.550000
# max      187.767000

# %%
# Plot the hourly rate column
sns.kdeplot(df['HourlyRate']);

# %% [markdown]
# How can we describe this distribution?
#
# - Extreme high postive values, outliers
# - Bimodal or maybe even trimodal
# - Not perfectly normal, but it is kinda normal

# %% [markdown]
# ### Using Z-Scores

# %%
# Grab a sample row
sample_row = df.sample(1)
sample_row
# Out:
#                     Department LastName FirstName            JobTitle  \
# 9356  Seattle Public Utilities      Yee     Julie  Admin Staff Anlyst
#
#       HourlyRate
# 9356       46.68

# %%
# Calculate the z-score for that row's HourlyRate
(sample_row['HourlyRate'].values[0] - df['HourlyRate'].mean()) / df['HourlyRate'].std()
# Out:
# -0.06801354134238283

# %%
((sample_row['HourlyRate'].values[0] - df['HourlyRate'].mean()) / df['HourlyRate'].std()) * df['HourlyRate'].std()
# Out:
# -1.1373311440497602

# %%
df['HourlyRate'].mean()
# Out:
# 47.81733114404976

# %%
df['HourlyRate'].std()
# Out:
# 16.722127999840367

# %%
df['HourlyRate'].std() * 2
# Out:
# 33.444255999680735

# %%
# Standardize the column
mu = df['HourlyRate'].mean()
sigma = df['HourlyRate'].std()
standardized_rate = [(x-mu)/sigma for x in df['HourlyRate']]
standardized_rate
# Out:
# [0.35418152857141033,
#  -0.4806404510315006,
#  -1.0983847955370931,
#  -1.0983847955370931,
#  2.9509802135482586,
#  -1.3298146709714245,
#  -1.460180854032624,
#  -1.1665579371379038,
#  -0.4638961706383189,
#  -0.2904732665660811,
#  -0.8298782992321454,
#  0.35418152857141033,
#  -0.6785817656794688,
#  -0.2904732665660811,
#  -0.595458373727603,
#  0.724409528264936,
#  -1.185096247573212,
#  -1.0601121546383923,
#  -0.2904732665660811,
#  0.5192322924470574,
#  -0.6528673350756543,
#  -0.6528673350756543,
#  0.8750482508021664,
#  -0.32156978729627567,
#  0.3368392381641866,
#  0.8204499365201133,
#  1.1764452978794346,
#  -0.6409071347948101,
#  -1.460180854032624,
#  0.6513925055503835,
#  -0.5284812521548768,
#  2.908880308559687,
#  -0.6528673350756543,
#  -0.5284812521548768,
#  -0.9177857712963488,
#  0.9635537328804118,
#  -1.1235012161268654,
#  -1.2090166481348998,
#  0.7912072468334499,
#  0.4460358667282923,
#  -0.7951937184176976,
#  0.24444669099466665,
#  2.44523716457263,
#  -0.530275282197003,
#  -0.21990808490910152,
#  1.490998565265632,
#  1.2691368500559763,
#  0.46899945126751236,
#  0.5933855341882902,
#  -1.7496177008290485,
#  -0.03930906066835742,
#  1.3630244222606012,
#  -0.46270015061023473,
#  -0.0548573210334545,
#  0.7345158975022493,
#  0.9647497529084964,
#  0.7476721178111777,
#  2.559642460359043,
#  -0.564959863011451,
#  0.5168402523908886,
#  0.899148054368067,
#  1.490998565265632,
#  -0.46270015061023473,
#  0.45584323095858403,
#  1.0603715541538443,
#  0.8397656599736764,
#  -1.7496177008290485,
#  0.775180578457119,
#  0.11976160306686794,
#  2.385023536258721,
#  0.45584323095858403,
#  -0.7192464466343385,
#  -1.1235012161268654,
#  -1.0601121546383923,
#  0.9270751220238376,
#  1.8122495448091016,
#  1.4340082109274102,
#  -0.7036981862692413,
#  -0.01479065009262701,
#  -0.7981837684879088,
#  0.6220900148623156,
#  0.8464035711295447,
#  -1.7496177008290485,
#  -1.3878216423335177,
#  -1.0601121546383923,
#  0.7883367987660472,
#  3.1739781477845947,
#  1.3026254108423387,
#  -1.1235012161268654,
#  -0.7036981862692413,
#  -0.7036981862692413,
#  -0.7036981862692413,
#  1.3026254108423387,
#  -0.685159875833933,
#  -0.10568817222704156,
#  1.7977777024692803,
#  0.4274377552915799,
#  -0.3580483981528498,
#  -0.6409071347948101,
#  -0.48363050110171185,
#  2.19724839184947,
#  1.5801020573579194,
#  0.21364917527149332,
#  0.4056103897790395,
#  -0.2677488860324773,
#  0.7787686385413722,
#  -0.9847628928690749,
#  0.9387363172976605,
#  1.9743102586145374,
#  1.175847287865393,
#  0.9354472622204285,
#  -1.705962969803968,
#  0.7787686385413722,
#  -0.5374514023655097,
#  -0.7981837684879088,
#  -0.7036981862692413,
#  -0.7036981862692413,
#  -0.8394464594568204,
#  0.7787686385413722,
#  -0.8394464594568204,
#  -0.9847628928690749,
#  0.8861712370633513,
#  1.4539219443950153,
#  0.8888024811251368,
#  2.32393681332431,
#  3.0440305717332246,
#  0.8888024811251368,
#  2.0707692738795442,
#  0.7058114168282236,
#  -0.8233001890776813,
#  0.7787686385413722,
#  0.28182231687230413,
#  1.2260203280435333,
#  -0.8215061590355546,
#  -0.10568817222704156,
#  1.525085136066037,
#  -0.7981837684879088,
#  -0.7036981862692413,
#  -1.0601121546383923,
#  -0.8233001890776813,
#  0.826011429650706,
#  0.826011429650706,
#  0.6304621550589065,
#  -0.2928653066222498,
#  0.5383686128964078,
#  0.35418152857141033,
#  -0.9333340316614458,
#  1.3026254108423387,
#  0.6884691264209998,
#  0.25730390629657374,
#  -0.7036981862692413,
#  -0.5356573723233831,
#  -0.4854245311438381,
#  1.301489191815659,
#  0.5371725928683232,
#  -0.8233001890776813,
#  -0.3580483981528498,
#  3.3101450279820037,
#  -0.9847628928690749,
#  -0.7222364967045493,
#  0.03484418107287547,
#  -1.0194474736835226,
#  0.826011429650706,
#  0.45584323095858403,
#  -0.7036981862692413,
#  0.45584323095858403,
#  1.5723877281767755,
#  -0.5966543937556872,
#  1.6140092251541127,
#  1.2972433207159595,
#  1.3026254108423387,
#  1.490998565265632,
#  0.5628870234721378,
#  1.4539219443950153,
#  -0.7036981862692413,
#  -0.6295449445280085,
#  -0.7036981862692413,
#  3.1504763542327363,
#  0.5606145854187776,
#  0.6011596643708386,
#  -1.2592494893144446,
#  -0.3921349689532552,
#  -1.7496177008290485,
#  -0.09133593189002864,
#  -0.7036981862692413,
#  -0.7389807770977309,
#  -0.5386474223935939,
#  -0.3682145683915673,
#  0.3314571480378066,
#  2.385023536258721,
#  0.5771196618063426,
#  0.7787686385413722,
#  0.4062083997930816,
#  0.7787686385413722,
#  -0.3580483981528498,
#  0.05756856160647921,
#  2.152397640796305,
#  0.23218748570680164,
#  -0.37897874864432685,
#  -0.6785817656794688,
#  0.8252938176338553,
#  -0.5105409517336106,
#  2.086018529237621,
#  -0.9638325423775981,
#  1.3815627326959095,
#  1.3493299929390348,
#  -0.9847628928690749,
#  0.7016253467299282,
#  1.5244871260519952,
#  -1.7496177008290485,
#  0.5706611536546865,
#  1.137574646966692,
#  0.23218748570680164,
#  2.152397640796305,
#  0.826011429650706,
#  0.826011429650706,
#  1.928741895544522,
#  -0.8394464594568204,
#  0.7638183881903172,
#  -0.08655185177769115,
#  0.8699053646814031,
#  -1.3752634320386314,
#  0.7793666485554144,
#  0.6011596643708386,
#  1.810335912764167,
#  0.7422900276847977,
#  2.152577043800518,
#  -0.7036981862692413,
#  0.4056103897790395,
#  1.3026254108423387,
#  0.23218748570680164,
#  -0.1714692737716832,
#  -0.32156978729627567,
#  0.23218748570680164,
#  1.2434224194521613,
#  0.4068064098071237,
#  -0.3712046184617781,
#  1.0694613063672849,
#  1.3026254108423387,
#  -0.7981837684879088,
#  -0.10509016221299905,
#  -0.6277509144858817,
#  -0.24203445542866275,
#  -0.8215061590355546,
#  0.8733738227628479,
#  0.7022233567439706,
#  0.4909464187828614,
#  0.45584323095858403,
#  -0.39751705907963475,
#  2.152397640796305,
#  0.8726562107459972,
#  0.23218748570680164,
#  0.5563089133176736,
#  0.9276731320378797,
#  -1.2335350587106302,
#  2.59133699110328,
#  0.7632203781762747,
#  -1.2335350587106302,
#  1.5327396642457771,
#  -0.1714692737716832,
#  -1.7496177008290485,
#  -1.7496177008290485,
#  0.5776578708189801,
#  1.1406244980383076,
#  0.8870084510830102,
#  -0.1810374339963586,
#  -0.3580483981528498,
#  -0.2677488860324773,
#  -0.1810374339963586,
#  0.7165755970809832,
#  1.178538332928583,
#  1.490998565265632,
#  1.9263498554883536,
#  2.3622991557251165,
#  0.5371725928683232,
#  0.8397656599736764,
#  0.8888024811251368,
#  0.32188898781313163,
#  1.1524650963163425,
#  1.3570443221201796,
#  0.6627546958171853,
#  0.5383686128964078,
#  0.1562402139234421,
#  1.5149189658273203,
#  -1.1235012161268654,
#  -0.3580483981528498,
#  0.23218748570680164,
#  -0.5416374724638051,
#  0.45584323095858403,
#  1.218425600865197,
#  -1.0601121546383923,
#  3.169194067672257,
#  -1.1235012161268654,
#  0.8623704385044716,
#  0.23218748570680164,
#  0.8397656599736764,
#  -1.3316087010135509,
#  0.23218748570680164,
#  0.9276731320378797,
#  -1.2335350587106302,
#  0.7632203781762747,
#  1.8122495448091016,
#  1.1724386307853523,
#  1.309203520996803,
#  1.1764452978794346,
#  -0.8663569100887196,
#  0.6011596643708386,
#  0.8397656599736764,
#  -0.3969190490655927,
#  0.8098651592715664,
#  -0.3682145683915673,
#  0.8397656599736764,
#  -0.3712046184617781,
#  0.18195464452725665,
#  0.700429326701844,
#  1.3630244222606012,
#  -1.0601121546383923,
#  0.8397656599736764,
#  -0.06801354134238283,
#  0.7422900276847977,
#  0.4313248203828541,
#  0.3936501894981953,
#  -0.37897874864432685,
#  -0.8233001890776813,
#  0.6537845456065523,
#  0.11976160306686794,
#  1.0018263737791122,
#  0.7632203781762747,
#  0.38109197920330906,
#  0.46899945126751236,
#  1.1524650963163425,
#  0.6220900148623156,
#  0.6537845456065523,
#  0.38228799923139367,
#  0.007335720426934229,
#  0.09524319249113752,
#  1.1803921639721133,
#  -0.2677488860324773,
#  0.6011596643708386,
#  1.0682054853377971,
#  -0.7036981862692413,
#  0.7997587900342534,
#  -1.3017082003114409,
#  0.469717063284363,
#  -0.9847628928690749,
#  -0.5966543937556872,
#  0.8520846662629459,
#  0.2002537509569478,
#  2.1381650024621006,
#  -0.5105409517336106,
#  -0.4937966713404289,
#  0.8324101368009575,
#  0.45584323095858403,
#  -1.7496177008290485,
#  0.25670589628253165,
#  1.1081525542758157,
#  -0.7389807770977309,
#  -0.18641952412273818,
#  0.9270751220238376,
#  0.45034153882939587,
#  -1.7496177008290485,
#  -0.06801354134238283,
#  -1.7496177008290485,
#  2.8903838588253623,
#  -0.5386474223935939,
#  -0.79040963830536,
#  -0.27193495613077273,
#  0.2746461967037975,
#  1.3026254108423387,
#  -0.7389807770977309,
#  0.46899945126751236,
#  5.588742584486997,
#  1.928741895544522,
#  0.7632203781762747,
#  -0.4244275097115339,
#  -0.5870862335310122,
#  -0.2157220148108061,
#  0.10002727260347545,
#  -0.5374514023655097,
#  -1.0601121546383923,
#  1.0633616042240552,
#  0.8098651592715664,
#  -0.21990808490910152,
#  -0.49200264129830223,
#  -1.0601121546383923,
#  0.6089337945533874,
#  -0.04887722089303241,
#  1.3026254108423387,
#  0.8188353094821993,
#  1.480234385012872,
#  -0.5870862335310122,
#  -0.5105409517336106,
#  -0.7222364967045493,
#  -1.1235012161268654,
#  0.2094631051731979,
#  0.35418152857141033,
#  0.6537845456065523,
#  0.6418243453257082,
#  0.8483172031744799,
#  -0.06801354134238283,
#  0.9151149217429935,
#  -0.79040963830536,
#  6.218770054681017,
#  -1.3692833318982094,
#  0.4056103897790395,
#  -0.3712046184617781,
#  0.28122430685826205,
#  0.38109197920330906,
#  1.5023607555324336,
#  0.3596234196991944,
#  -0.8233001890776813,
#  -0.3712046184617781,
#  -0.5882822535590968,
#  1.291263220575537,
#  0.18195464452725665,
#  0.4295307903407274,
#  -0.7425688371819842,
#  0.7632203781762747,
#  -0.9847628928690749,
#  1.124239023653551,
#  0.8928689492206237,
#  0.5192322924470574,
#  -0.7634991876734613,
#  1.309203520996803,
#  1.1824253980198571,
#  0.2094631051731979,
#  1.1764452978794346,
#  0.7632203781762747,
#  0.18195464452725665,
#  0.18195464452725665,
#  0.007335720426934229,
#  0.6059437444831764,
#  0.7321238574460807,
#  -0.1810374339963586,
#  0.8397656599736764,
#  0.8397656599736764,
#  0.6220900148623156,
#  -0.8233001890776813,
#  -1.7496177008290485,
#  0.6884691264209998,
#  0.3188989377429204,
#  -0.9847628928690749,
#  -0.8215061590355546,
#  -0.5374514023655097,
#  1.2733229201542713,
#  -1.1235012161268654,
#  1.3271438214180695,
#  0.8427557100438873,
#  0.9961452786457113,
#  0.32188898781313163,
#  -1.0816405151439115,
#  0.7321238574460807,
#  -0.9333340316614458,
#  0.5491327931491674,
#  -0.7981837684879088,
#  1.1995882854228677,
#  0.7883367987660472,
#  0.10002727260347545,
#  0.8336659578304462,
#  0.007335720426934229,
#  0.38109197920330906,
#  -0.3712046184617781,
#  -0.5966543937556872,
#  0.7998185910356576,
#  -0.39751705907963475,
#  1.4921945852937162,
#  1.0329826955107109,
#  -0.685159875833933,
#  -0.9847628928690749,
#  0.7787686385413722,
#  -0.4160553695149431,
#  1.490998565265632,
#  0.7321238574460807,
#  0.14487802365664043,
#  0.2692641065774179,
#  0.11976160306686794,
#  0.7494661478533043,
#  0.3188989377429204,
#  -1.7496177008290485,
#  0.21364917527149332,
#  0.8397656599736764,
#  1.3026254108423387,
#  1.7481428713037777,
#  -0.5386474223935939,
#  -0.7981837684879088,
#  -0.46270015061023473,
#  -0.32156978729627567,
#  1.620407932304364,
#  -0.7389807770977309,
#  0.1562402139234421,
#  0.4833516916045253,
#  -0.8233001890776813,
#  0.45584323095858403,
#  0.2094631051731979,
#  0.9270751220238376,
#  -1.2335350587106302,
#  -1.0601121546383923,
#  -0.0548573210334545,
#  3.1563966533717545,
#  -0.5679499130816618,
#  -1.3298146709714245,
#  1.1764452978794346,
#  -0.7389807770977309,
#  -0.6409071347948101,
#  -0.6295449445280085,
#  0.4056103897790395,
#  -1.7496177008290485,
#  2.2833618338715467,
#  1.0927238959135273,
#  -0.004624479853909512,
#  0.19451285482214292,
#  0.5103219432378285,
#  -0.7192464466343385,
#  -0.2677488860324773,
#  0.7321238574460807,
#  -0.9847628928690749,
#  -0.5870862335310122,
#  -1.7496177008290485,
#  1.411283830393807,
#  0.7321238574460807,
#  0.3292445109858505,
#  0.5754452337670241,
#  0.5754452337670241,
#  1.1246576306633802,
#  -1.0074872734026787,
#  0.5964353852599051,
#  0.45584323095858403,
#  0.4588332810287953,
#  0.8397656599736764,
#  0.3368392381641866,
#  -0.06801354134238283,
#  -0.4202414396132385,
#  0.6220900148623156,
#  -0.9847628928690749,
#  -0.3867528788268752,
#  0.9358658692302578,
#  -1.1235012161268654,
#  0.10002727260347545,
#  1.4316161708712418,
#  2.6443804793488233,
#  -0.3580483981528498,
#  0.6011596643708386,
#  0.5006939820117491,
#  -0.09133593189002864,
#  -1.0044972233324676,
#  0.9013606914200231,
#  -1.0601121546383923,
#  0.8134532193558197,
#  0.8397656599736764,
#  0.4941158718572849,
#  -0.8663569100887196,
#  -1.0601121546383923,
#  -1.5283539956334344,
#  -0.5512056326884801,
#  1.5936170836752732,
#  0.5282024426576902,
#  -0.7036981862692413,
#  0.4432850206636978,
#  -1.0601121546383923,
#  0.8750482508021664,
#  0.06952876188732296,
#  0.4068064098071237,
#  -0.7634991876734613,
#  -1.2335350587106302,
#  -1.7496177008290485,
#  -0.06801354134238283,
#  1.6817637597450936,
#  -0.1810374339963586,
#  -1.7496177008290485,
#  0.5754452337670241,
#  -1.3878216423335177,
#  0.32188898781313163,
#  -1.0601121546383923,
#  1.218425600865197,
#  -1.0601121546383923,
#  0.34879943844503036,
#  -0.7634991876734613,
#  -0.11107026235342114,
#  -1.2454952589914743,
#  0.5754452337670241,
#  -1.7496177008290485,
#  -0.31379565711372687,
#  1.426473284750479,
#  0.2746461967037975,
#  -0.3682145683915673,
#  1.0973943541231963,
#  2.5656823615008695,
#  0.46899945126751236,
#  -0.9847628928690749,
#  -0.8215061590355546,
#  0.6011596643708386,
#  1.0676074753237546,
#  -0.9147957212261375,
#  -0.4202414396132385,
#  -0.8394464594568204,
#  -0.6881499259041438,
#  -0.3712046184617781,
#  -0.41904541958515396,
#  0.31112480756037203,
#  0.6011596643708386,
#  -0.5829001634327168,
#  -0.6277509144858817,
#  -1.2849639199182594,
#  -0.7036981862692413,
#  -0.7036981862692413,
#  -0.6409071347948101,
#  -0.9847628928690749,
#  -0.3682145683915673,
#  0.4983019419555803,
#  -1.3298146709714245,
#  0.8395264559680596,
#  0.7494661478533043,
#  -0.6881499259041438,
#  -0.895061390762745,
#  -1.3692833318982094,
#  0.8134532193558197,
#  0.4056103897790395,
#  1.4502142823079538,
#  -1.7496177008290485,
#  -1.7496177008290485,
#  -0.39751705907963475,
#  -0.37000859843369355,
#  -1.7496177008290485,
#  -0.7036981862692413,
#  -0.31379565711372687,
#  -0.6277509144858817,
#  -1.2335350587106302,
#  -1.0601121546383923,
#  -1.445828613695611,
#  -1.0930027054107132,
#  0.45584323095858403,
#  0.6693328059716493,
#  0.45584323095858403,
#  1.1262124566998906,
#  0.4492651208041199,
#  -0.06801354134238283,
#  1.1082721562786237,
#  0.7826557036326465,
#  0.8397656599736764,
#  1.3026254108423387,
#  0.8262506336563228,
#  -0.6403091247807681,
#  0.3368392381641866,
#  -1.3692833318982094,
#  -1.3298146709714245,
#  -0.4202414396132385,
#  0.10002727260347545,
#  1.1764452978794346,
#  -0.02854488041559742,
#  0.8098651592715664,
#  1.2159139588062204,
#  -0.8233001890776813,
#  -0.6277509144858817,
#  1.8171532269242474,
#  0.5228203525313107,
#  -0.37897874864432685,
#  -0.5685479230957039,
#  0.5327473187644111,
#  1.8653528340560495,
#  -0.2611707758780132,
#  -0.06801354134238283,
#  -0.5105409517336106,
#  0.6249006619283143,
#  -0.5105409517336106,
#  0.5718571736827711,
#  0.38707207934373117,
#  0.35418152857141033,
#  -0.14037275304148905,
#  -0.27193495613077273,
#  1.0373481686132193,
#  -0.4160553695149431,
#  -0.4160553695149431,
#  0.582980159943956,
#  1.3425126787789536,
#  -0.5966543937556872,
#  -0.6295449445280085,
#  -0.10509016221299905,
#  -0.3682145683915673,
#  -0.1714692737716832,
#  -1.3298146709714245,
#  -0.9847628928690749,
#  0.18398787857500007,
#  0.45285318088837323,
#  0.44986313081816237,
#  -0.44894592028726393,
#  0.6011596643708386,
#  -0.06801354134238283,
#  0.44986313081816237,
#  0.5282024426576902,
#  0.44986313081816237,
#  0.27943027681613536,
#  1.6844548048082837,
#  1.2402529663777377,
#  1.1423587270790296,
#  0.10002727260347545,
#  0.6011596643708386,
#  1.0694015053658814,
#  -1.7496177008290485,
#  0.819014712486412,
#  -1.3172564606765382,
#  0.4056103897790395,
#  -0.8053598886564151,
#  -0.7036981862692413,
#  -0.3568523781247652,
#  0.44986313081816237,
#  3.247533379511786,
#  1.1764452978794346,
#  -0.3682145683915673,
#  2.7402355044996467,
#  -0.8215061590355546,
#  0.5192920934484615,
#  -1.0601121546383923,
#  1.7544817774526256,
#  1.2008441064523565,
#  -0.5105409517336106,
#  -0.27193495613077273,
#  -0.27193495613077273,
#  0.03962826118521297,
#  0.32188898781313163,
#  -0.4854245311438381,
#  0.8397656599736764,
#  -0.1810374339963586,
#  -0.7981837684879088,
#  0.46541139118325947,
#  0.9486034825293568,
#  -1.1055609157055994,
#  0.21364917527149332,
#  -0.3849588487847485,
#  0.6011596643708386,
#  -0.8215061590355546,
#  -0.11107026235342114,
#  1.1764452978794346,
#  0.45285318088837323,
#  0.38707207934373117,
#  1.076577625534387,
#  0.46720542122538616,
#  -0.3682145683915673,
#  -0.9847628928690749,
#  -0.9847628928690749,
#  -0.3682145683915673,
#  1.0586373251131214,
#  0.6555785756486789,
#  -0.4160553695149431,
#  2.507579708536529,
#  0.44986313081816237,
#  -0.530275282197003,
#  2.5164063363437923,
#  1.1100661863207504,
#  0.4520757678701185,
#  0.4056103897790395,
#  0.46541139118325947,
#  1.490998565265632,
#  0.6011596643708386,
#  0.7022233567439706,
#  0.8031076461128895,
#  0.8397656599736764,
#  0.44986313081816237,
#  0.8229735387793715,
#  0.04620637133967755,
#  1.124239023653551,
#  0.2094631051731979,
#  0.9270751220238376,
#  0.44986313081816237,
#  -0.1810374339963586,
#  -0.44894592028726393,
#  1.0927238959135273,
#  0.6848810663367468,
#  -0.06801354134238283,
#  1.1100661863207504,
#  0.8397656599736764,
#  0.32188898781313163,
#  -0.49200264129830223,
#  -1.7496177008290485,
#  0.8060976961831005,
#  -0.06801354134238283,
#  0.45584323095858403,
#  -1.1235012161268654,
#  -0.7981837684879088,
#  0.029462090946495892,
#  0.5108601522504665,
#  0.7285357973618273,
#  1.8124289478133144,
#  0.4056103897790395,
#  0.2094631051731979,
#  1.0191686641863364,
#  -0.06801354134238283,
#  -0.4310056198659981,
#  1.3024460078381261,
#  -1.3316087010135509,
#  0.2537158462123208,
#  -0.3682145683915673,
#  0.7016253467299282,
#  1.3026254108423387,
#  1.1764452978794346,
#  1.7200364006437945,
#  -0.7981837684879088,
#  0.019893930721820476,
#  1.291263220575537,
#  1.124239023653551,
#  0.44986313081816237,
#  0.32188898781313163,
#  -1.7496177008290485,
#  0.9121846726741867,
#  1.2362462992836545,
#  -0.05904339113174991,
#  -0.11107026235342114,
#  -1.6928067494950394,
#  0.805679089173271,
#  -0.06801354134238283,
#  -1.6928067494950394,
#  -0.7036981862692413,
#  -0.8233001890776813,
#  -0.8233001890776813,
#  0.32188898781313163,
#  0.5126541822925932,
#  -0.3849588487847485,
#  -0.9847628928690749,
#  -0.004624479853909512,
#  -0.004624479853909512,
#  -0.7036981862692413,
#  0.24474569600168747,
#  0.14428001364259793,
#  -0.17924340395423194,
#  -0.004624479853909512,
#  -0.004624479853909512,
#  -0.004624479853909512,
#  0.5718571736827711,
#  -0.8233001890776813,
#  0.9025567114481072,
#  0.8397656599736764,
#  -0.5829001634327168,
#  -0.3712046184617781,
#  0.2052770350749025,
#  1.3026254108423387,
#  0.8397656599736764,
#  -0.5105409517336106,
#  0.21364917527149332,
#  -0.7036981862692413,
#  1.3026254108423387,
#  0.8397656599736764,
#  0.8397656599736764,
#  1.1724386307853523,
#  -0.06801354134238283,
#  0.003747660342681319,
#  -0.27193495613077273,
#  -0.750940977378575,
#  0.31112480756037203,
#  0.025874030862242558,
#  -0.2587787358218444,
#  0.38707207934373117,
#  1.3791706926397405,
#  -0.9147957212261375,
#  1.6560493291412794,
#  -1.7496177008290485,
#  2.7223011841785216,
#  0.5754452337670241,
#  0.5909934941321215,
#  0.6011596643708386,
#  -0.06801354134238283,
#  0.31040719554352136,
#  0.7989813770159983,
#  -1.0074872734026787,
#  -1.2335350587106302,
#  0.8397656599736764,
#  -0.7587151075611234,
#  0.7943168989064694,
#  -0.7036981862692413,
#  -0.7036981862692413,
#  0.7924630678629386,
#  -0.4202414396132385,
#  -1.7496177008290485,
#  -0.8233001890776813,
#  0.2094631051731979,
#  -0.7198444566483805,
#  1.490998565265632,
#  0.26089196638082707,
#  0.020432139734458475,
#  -1.0601121546383923,
#  -0.6869539058760596,
#  0.21364917527149332,
#  -0.9847628928690749,
#  -0.8388484494427784,
#  -0.1714692737716832,
#  -0.49200264129830223,
#  0.21364917527149332,
#  0.025874030862242558,
#  0.38707207934373117,
#  1.6560493291412794,
#  -0.7389807770977309,
#  0.31112480756037203,
#  0.7422900276847977,
#  1.565749817020907,
#  0.45285318088837323,
#  0.33982928823439745,
#  -0.7634991876734613,
#  0.38707207934373117,
#  0.6198175768089556,
#  0.04620637133967755,
#  1.1724386307853523,
#  -0.6881499259041438,
#  -0.530275282197003,
#  2.207892970099421,
#  -0.505756871621273,
#  -0.31379565711372687,
#  0.45584323095858403,
#  0.21364917527149332,
#  -1.3298146709714245,
#  -0.2677488860324773,
#  0.11437951294048794,
#  1.1863722641125358,
#  -0.5834981734467589,
#  -0.6785817656794688,
#  1.6543151001005565,
#  -0.5105409517336106,
#  0.4056103897790395,
#  0.38707207934373117,
#  0.38707207934373117,
#  -0.5529996627306069,
#  0.38707207934373117,
#  0.23637355580509706,
#  -0.9847628928690749,
#  0.5259300046043301,
#  0.6581500187090604,
#  0.38707207934373117,
#  0.38707207934373117,
#  0.38707207934373117,
#  -1.3692833318982094,
#  0.5042820420960024,
#  -0.7981837684879088,
#  0.21364917527149332,
#  -1.7496177008290485,
#  0.32188898781313163,
#  0.38707207934373117,
#  -0.8663569100887196,
#  -0.49200264129830223,
#  -0.21990808490910152,
#  1.0708965304009863,
#  -0.7186484366202963,
#  0.38707207934373117,
#  0.9791617942469134,
#  -0.9847628928690749,
#  -0.0766248855445904,
#  -1.3017082003114409,
#  -0.3377160576754148,
#  -1.0601121546383923,
#  1.3026254108423387,
#  -0.4160553695149431,
#  0.019893930721820476,
#  0.45584323095858403,
#  -1.7496177008290485,
#  -1.7496177008290485,
#  -0.49200264129830223,
#  -0.6785817656794688,
#  -1.6928067494950394,
#  0.14069195355834502,
#  -0.009408559966247433,
#  0.45584323095858403,
#  -1.0044972233324676,
#  0.06396726875673071,
#  -1.7496177008290485,
#  -0.07997374162322698,
#  -0.10509016221299905,
#  0.019893930721820476,
#  -0.5966543937556872,
#  -0.16728320367338778,
#  -0.79040963830536,
#  0.5078701021802557,
#  -0.8215061590355546,
#  1.545537078546281,
#  1.7592658575649631,
#  -1.6928067494950394,
#  0.1323198133617542,
#  -0.06801354134238283,
#  0.5042820420960024,
#  0.38707207934373117,
#  0.6011596643708386,
#  1.1764452978794346,
#  0.5096043312209778,
#  -0.13140260283085614,
#  0.33654023315716536,
#  1.152524897317747,
#  0.825473220638068,
#  -0.5374514023655097,
#  -1.0601121546383923,
#  -0.10509016221299905,
#  0.34042729824843954,
#  -0.9847628928690749,
#  -1.6928067494950394,
#  0.9608626878172217,
#  1.1615548485297842,
#  0.3936501894981953,
#  -1.0074872734026787,
#  1.6560493291412794,
#  0.11557553296857252,
#  -0.0548573210334545,
#  -0.22947624513377693,
#  0.6077377745253028,
#  -0.10509016221299905,
#  -1.7496177008290485,
#  0.4492651208041199,
#  ...]

# %%
# Visualize it
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)
# Can toggle sharex to see the impact of the scale

sns.kdeplot(df['HourlyRate'], ax=ax1, label='Without Scaling')
ax1.legend()

sns.kdeplot(standardized_rate, ax=ax2, label='With Scaling')
ax2.legend()

plt.show()

# %% [markdown]
# Let's discuss:

# %% [markdown]
# ## Central Limit Theorem (CLT)
#
# We mentioned that the distribution above doesn't seem very normal. But here's something cool:
#
# > "The central limit theorem states that the sampling distribution of the mean of any independent, random variable will be normal or nearly normal, if the sample size is large enough."
# - From [Stat Trek](https://stattrek.com/statistics/dictionary.aspx?definition=central_limit_theorem)

# %% [markdown]
# Let's look at an example, using the popular Iris dataset:
#
# <img src="images/probability-basics.gif" width=800>
#
# Here, taking samples of 15 flowers at a time and measuring their sepal lengths, we see that the the mean of the samples is normally distributed, where the mean of that normal distribution approximates the population mean.
#
# The coolest part is - this is true and works almost no matter what the original distribution is! (I say 'almost' because there are exceptions, of course). Even when we have _distinctly non-normal distributions_, we can use sampling to get a representation of population parameters (like the population mean).

# %% [markdown]
# ## Revisiting Sampling
#
# Before we apply a theorem that's related to sampling, we should remember some key things about sampling.
#
# <img src="images/sample_pop.png" alt="sampling example with circled people" width=800>
#
# Our goal when sampling is to find a representative group, from which we can infer population parameters.
#
# Remember: samples have statistics, populations have parameters.
#
# In order to do this effectively, our sample should be randomly selected and representative of our population (which sounds nice and easy, it's hard to do in practice). We are trying to minimize bias in our sample, but also we are sampling because we're trying to minimize cost as well.

# %% [markdown]
# ### Back to our Seattle Data

# %% [markdown]
# Let's take 100 samples of 50 employees each time, and see what their average hourly rate is:

# %%
df
# Out:
#                         Department     LastName  FirstName  \
# 0         Seattle Public Utilities    Batchelor      Craig
# 1         Finance & Admin Services       Altice    Jeffrey
# 2         Finance & Admin Services       Montes    Valeria
# 3                  Fire Department       Kuklok    Rebecca
# 4      Planning & Comm Development  Quirindongo       Rico
# ...                            ...          ...        ...
# 11734           Seattle City Light      Lapchis  Alexandra
# 11735            Police Department   Whitehouse     Nathan
# 11736            Police Department      Trailor   Brieanna
# 11737     Finance & Admin Services      Mercado     Victor
# 11738              Fire Department       Borbon    Matthew
#
#                    JobTitle  HourlyRate
# 0      Civil Engrng Spec,Sr      53.740
# 1             Auto Mechanic      39.780
# 2              Cust Svc Rep      29.450
# 3            Cust Svc Rep *      29.450
# 4                Executive3      97.164
# ...                     ...         ...
# 11734        Elctn-Con Aprn      41.450
# 11735           Pol Recruit      33.440
# 11736           Pol Recruit      33.440
# 11737         Actg Tech III      30.720
# 11738        Cust Svc Rep *      29.450
#
# [11739 rows x 5 columns]

# %%
k = 1000 # number of samples
n = 50 # number of employees per sample

# The full for loop version:
sample_means = []
for x in range(n):
     sample_emps = df.sample(n=n)
     sample_mean = sample_emps['HourlyRate'].mean()
     sample_means.append(sample_mean)
    
# But let's do this with list comprehension:
#sample_means = [df.sample(n=n)['HourlyRate'].mean() for x in range(1000)]

# %%
sample_means = [df.sample(n=n)['HourlyRate'].mean() for x in range(1000)]

# %%
sample_means
# Out:
# [51.497240000000005,
#  48.86866,
#  50.535717999999996,
#  48.379436000000005,
#  50.91634,
#  51.386092,
#  49.505105999999984,
#  48.639179999999996,
#  43.29728600000001,
#  46.16326599999999,
#  45.71153999999999,
#  45.711819999999996,
#  44.53086000000001,
#  47.455224,
#  49.890328,
#  47.60183400000002,
#  47.399868000000005,
#  47.32721999999999,
#  48.566182,
#  48.271176,
#  46.209536,
#  50.298669999999994,
#  46.97310200000001,
#  47.28728,
#  50.95038,
#  44.97646399999999,
#  47.699690000000004,
#  43.35669999999999,
#  48.653486,
#  48.661328,
#  48.977399999999996,
#  48.157357999999995,
#  48.020900000000005,
#  49.02746,
#  46.60223400000001,
#  48.56166,
#  48.093258000000006,
#  50.23214,
#  48.38158000000001,
#  47.30136,
#  47.7529,
#  52.134184,
#  47.460919999999994,
#  46.728531999999994,
#  48.627242,
#  42.40413,
#  49.42761400000001,
#  47.37661599999999,
#  52.281540000000014,
#  44.287240000000004,
#  50.07059999999999,
#  44.693702,
#  42.976279999999996,
#  48.66892,
#  41.267675999999994,
#  48.140919999999994,
#  50.10868000000001,
#  46.45772800000002,
#  49.047323999999996,
#  46.66348,
#  47.37556000000001,
#  49.06483600000001,
#  51.2472,
#  49.974156,
#  50.28189999999999,
#  49.551500000000004,
#  48.18139600000001,
#  44.29882,
#  45.153024,
#  47.68181,
#  48.968768,
#  47.57768,
#  45.87034,
#  40.703739999999996,
#  48.36815000000001,
#  43.989758,
#  52.60708,
#  46.953772,
#  45.73523000000001,
#  50.731677999999995,
#  46.54054,
#  48.615759999999995,
#  46.073626000000004,
#  49.933082000000006,
#  50.19471000000001,
#  46.665257999999994,
#  46.56714999999999,
#  44.17223800000001,
#  47.025158000000005,
#  44.9742,
#  48.02046,
#  45.1975,
#  48.681079999999994,
#  51.380696,
#  47.106,
#  50.732290000000006,
#  47.45855,
#  47.7822,
#  48.261412,
#  49.486526,
#  49.786100000000005,
#  47.282864,
#  50.795252,
#  47.44320400000001,
#  50.900780000000005,
#  48.46634,
#  48.16172,
#  47.77724,
#  50.003679999999996,
#  47.87357000000001,
#  46.83785999999999,
#  45.39586,
#  42.771939999999994,
#  46.55363400000001,
#  48.31112000000001,
#  50.397028,
#  48.0551,
#  47.142483999999996,
#  48.591768,
#  45.632183999999995,
#  53.899939999999994,
#  47.75518,
#  46.8138,
#  50.75210600000001,
#  46.23559600000001,
#  47.850206,
#  44.722470000000015,
#  48.0611,
#  44.3657,
#  48.682792,
#  51.842976,
#  48.20276,
#  48.31776,
#  50.90162599999999,
#  43.770407999999996,
#  46.813682,
#  49.970878,
#  49.25503,
#  49.849129999999995,
#  50.009494,
#  52.078230000000005,
#  51.545700000000004,
#  46.419256000000004,
#  48.00863999999999,
#  47.34335,
#  47.444642,
#  49.359372,
#  44.36579400000001,
#  54.64725199999999,
#  46.480146,
#  48.96965800000001,
#  52.56654,
#  48.64278,
#  47.301610000000004,
#  44.037690000000005,
#  40.574856,
#  45.49822,
#  49.419211999999995,
#  46.688014,
#  51.251006,
#  50.010654,
#  46.054912,
#  47.837939999999996,
#  50.378142,
#  50.81652,
#  48.227788000000004,
#  48.64088600000001,
#  45.12756000000001,
#  44.70880999999999,
#  48.17264,
#  48.249286000000005,
#  48.897256000000006,
#  48.171298,
#  50.00185999999999,
#  47.075677999999996,
#  49.295878,
#  45.948109999999986,
#  46.60224800000001,
#  48.731602,
#  44.47092000000001,
#  47.4026,
#  50.752914000000004,
#  48.608019999999996,
#  44.75168000000001,
#  44.49521999999999,
#  51.75448,
#  49.094526,
#  45.18333799999999,
#  53.11219800000001,
#  45.91153,
#  47.85162799999999,
#  49.007818,
#  47.018539999999994,
#  50.773198,
#  46.551041999999995,
#  50.360347999999995,
#  49.072304,
#  47.35938,
#  49.57137999999999,
#  44.481218,
#  45.9944,
#  54.45302400000001,
#  45.003484,
#  47.731759999999994,
#  49.84906599999999,
#  49.220774,
#  48.616066000000004,
#  44.39309000000001,
#  48.68013399999999,
#  47.79144,
#  47.514606,
#  47.70517999999999,
#  46.79366,
#  50.71495999999999,
#  48.44532,
#  46.08857999999999,
#  48.77789800000001,
#  45.2184,
#  50.0034,
#  50.498400000000004,
#  46.1973,
#  49.50425000000001,
#  46.985541999999995,
#  47.498239999999996,
#  51.83889,
#  45.338240000000006,
#  47.47956000000001,
#  46.085899999999995,
#  47.987742,
#  51.3147,
#  52.12778000000001,
#  52.8696,
#  49.607780000000005,
#  51.31308,
#  46.399486,
#  49.67537600000001,
#  52.928814,
#  51.72508400000001,
#  41.86007000000001,
#  48.143460000000005,
#  46.135603999999994,
#  49.63945400000001,
#  44.94668200000001,
#  46.707159999999995,
#  47.73502200000001,
#  50.5396,
#  47.335483999999994,
#  43.0681,
#  49.789559999999994,
#  49.684417999999994,
#  48.16963799999999,
#  48.6313,
#  44.902942,
#  51.19846399999999,
#  44.512804,
#  45.759705999999994,
#  51.671347999999995,
#  46.02639800000001,
#  53.915694,
#  45.74462,
#  45.59178,
#  48.51418,
#  44.214968,
#  46.35128999999999,
#  48.227248,
#  44.49443799999999,
#  47.695041999999994,
#  43.18512199999999,
#  43.843059999999994,
#  44.47241199999999,
#  42.507472,
#  48.00751999999999,
#  49.13157399999999,
#  49.0916,
#  47.55606000000001,
#  44.65404,
#  48.59497,
#  48.692789999999995,
#  47.55022000000001,
#  48.856432,
#  51.601310000000005,
#  49.16102,
#  44.753811999999996,
#  46.450419999999994,
#  49.81576,
#  49.538378,
#  47.554880000000004,
#  49.48552000000001,
#  49.94612,
#  49.001184,
#  45.74412,
#  46.368860000000005,
#  50.440149999999996,
#  48.124140000000004,
#  47.99717,
#  48.921062,
#  49.634022,
#  48.703739999999996,
#  50.317983999999996,
#  48.852158,
#  49.467547999999994,
#  46.262468,
#  52.005714,
#  47.40739599999999,
#  46.33314,
#  45.266072000000015,
#  46.608394,
#  47.66282,
#  43.799288,
#  47.34741999999999,
#  47.66661199999999,
#  45.84876400000001,
#  45.793012,
#  46.85293999999999,
#  47.514497999999996,
#  47.48004,
#  49.243083999999996,
#  44.492020000000004,
#  47.422979999999995,
#  50.22699200000001,
#  47.818454,
#  46.12952,
#  49.80543600000001,
#  46.87814,
#  45.34572,
#  46.659839999999996,
#  51.02364000000001,
#  48.15356,
#  45.901388000000004,
#  47.44456399999999,
#  47.038878000000004,
#  47.818548,
#  47.642115999999994,
#  50.87176599999999,
#  47.06648,
#  49.960635999999994,
#  48.93088000000001,
#  48.88546,
#  48.256651999999995,
#  47.84801400000001,
#  47.989708,
#  45.74676,
#  49.32710000000001,
#  45.176877999999995,
#  46.257778,
#  46.42681,
#  46.35000000000001,
#  43.927634,
#  46.970334,
#  45.897659999999995,
#  48.372592,
#  48.830203999999995,
#  46.438088,
#  48.429660000000005,
#  45.003420000000006,
#  52.468320000000006,
#  48.761359999999996,
#  49.021260000000005,
#  48.235960000000006,
#  46.786278,
#  48.516746000000005,
#  47.9896,
#  48.197478000000004,
#  45.529906000000004,
#  48.754633999999996,
#  46.822525999999996,
#  46.020540000000004,
#  47.294188000000005,
#  49.10989999999999,
#  45.963499999999996,
#  47.215351999999996,
#  46.571920000000006,
#  49.759422,
#  48.912488,
#  49.175328,
#  49.53574,
#  51.133773999999995,
#  44.84882000000002,
#  47.828059999999994,
#  46.551607999999995,
#  46.315560000000005,
#  48.103199999999994,
#  50.467484000000006,
#  47.496680000000005,
#  46.91094000000001,
#  46.587022,
#  47.56264,
#  47.50695599999999,
#  42.78304000000001,
#  50.11984,
#  49.20908,
#  48.409372000000005,
#  49.2602,
#  46.217014,
#  47.67432000000001,
#  51.18335200000001,
#  47.13074399999999,
#  51.232848,
#  49.171440000000004,
#  47.130796000000004,
#  48.772972,
#  46.152379999999994,
#  48.700700000000005,
#  50.73846799999999,
#  47.87850600000001,
#  49.83937999999999,
#  52.88406,
#  51.41504,
#  49.900299999999994,
#  47.788599999999995,
#  48.329063999999995,
#  47.114281999999996,
#  46.750604,
#  47.748512,
#  49.09743399999999,
#  49.70124999999999,
#  48.531148,
#  51.290398,
#  46.22871399999999,
#  47.59611999999999,
#  48.07182000000001,
#  47.35193999999999,
#  47.094922000000004,
#  46.61452400000001,
#  46.40322000000001,
#  48.74568,
#  46.717560000000006,
#  47.595136000000004,
#  50.045552,
#  48.479983999999995,
#  48.863095999999985,
#  46.08149,
#  51.00752000000001,
#  47.387710000000006,
#  46.276019999999995,
#  46.485148,
#  45.3021,
#  45.81116399999999,
#  51.34858,
#  51.36404000000002,
#  47.76814,
#  47.42406,
#  49.57725000000001,
#  44.676036,
#  52.408248000000015,
#  46.96920600000001,
#  44.66848,
#  49.55095199999999,
#  45.188376000000005,
#  47.464259999999996,
#  43.67988,
#  48.16150400000001,
#  47.418051999999996,
#  47.955462,
#  48.710544000000006,
#  48.64104,
#  44.977616,
#  51.035613999999995,
#  44.95828199999999,
#  46.12353999999999,
#  52.100609999999996,
#  42.69492800000001,
#  55.152079999999984,
#  47.48514,
#  44.298019999999994,
#  49.30804199999999,
#  50.04361999999999,
#  48.85387000000001,
#  48.618739999999995,
#  50.128636,
#  48.896837999999995,
#  48.487880000000004,
#  46.06210000000001,
#  50.529216000000005,
#  47.200959999999995,
#  46.107040000000005,
#  49.05388,
#  46.20509800000001,
#  46.775588000000006,
#  50.84016,
#  45.769328,
#  51.350636,
#  50.972030000000004,
#  50.774442,
#  45.78224,
#  48.761080000000014,
#  47.951282,
#  43.78305600000001,
#  47.182281999999994,
#  51.815039999999996,
#  49.12947,
#  47.965120000000006,
#  46.372236,
#  47.107519999999994,
#  44.97175,
#  48.1579,
#  50.401548000000005,
#  51.56456599999999,
#  48.212394,
#  48.93086,
#  48.24875999999999,
#  49.337419999999995,
#  42.558445999999996,
#  49.969356000000005,
#  49.270852000000005,
#  51.062654,
#  46.12245599999999,
#  47.321462000000004,
#  48.67193999999999,
#  46.1583,
#  50.975919999999995,
#  48.064918,
#  50.57417799999999,
#  47.13548,
#  49.604538000000005,
#  49.83626400000001,
#  48.47576,
#  41.574338,
#  48.753834,
#  46.06588,
#  48.814871999999994,
#  46.991816,
#  44.490342,
#  49.55826,
#  48.69696,
#  43.05216,
#  50.975404,
#  48.124204,
#  50.546186,
#  47.50461999999999,
#  49.05180399999999,
#  52.30158,
#  49.379616000000006,
#  48.47689199999999,
#  50.791959999999996,
#  50.39322,
#  48.48143,
#  49.885191999999996,
#  49.46691800000001,
#  49.10449,
#  51.25645200000001,
#  49.261296,
#  48.708732,
#  47.695491999999994,
#  45.908240000000006,
#  51.667812000000005,
#  44.911934,
#  43.565039999999996,
#  48.88141400000001,
#  52.348836,
#  48.04746,
#  47.976566000000005,
#  48.355748000000006,
#  51.410872,
#  46.883455999999995,
#  48.894748,
#  44.443059999999996,
#  49.25732000000001,
#  54.803202,
#  47.22299999999999,
#  50.859176,
#  46.63038400000001,
#  44.19276,
#  48.094061999999994,
#  50.066072000000005,
#  48.97754,
#  46.532008000000005,
#  48.26102,
#  46.32439600000001,
#  44.53468000000001,
#  47.80679800000001,
#  44.910599999999995,
#  46.486748,
#  48.505956000000005,
#  47.23389,
#  49.20834000000001,
#  51.041835999999996,
#  50.62836,
#  48.643060000000006,
#  48.385958,
#  48.676704,
#  44.222914,
#  48.455344,
#  39.2697,
#  46.55151800000001,
#  49.73411999999999,
#  47.769059999999996,
#  47.532726,
#  44.916799999999995,
#  47.66348599999999,
#  40.787259999999996,
#  44.717240000000004,
#  46.73136,
#  49.00845999999999,
#  46.99215800000001,
#  42.264586,
#  48.76616,
#  42.94212,
#  44.71943999999999,
#  48.03858999999999,
#  47.224166,
#  49.000020000000006,
#  48.95165,
#  48.44711399999999,
#  49.634508,
#  48.556819999999995,
#  44.38796,
#  48.00487999999999,
#  47.212160000000004,
#  46.222080000000005,
#  49.06804,
#  44.98111800000001,
#  48.32280000000001,
#  47.99438,
#  47.16240400000001,
#  46.71131400000001,
#  46.199555999999994,
#  51.93045,
#  46.172900000000006,
#  50.59232000000001,
#  49.746365999999995,
#  47.66227999999999,
#  49.069744,
#  48.308198000000004,
#  51.73531599999999,
#  45.75715,
#  51.743198,
#  46.503760000000014,
#  48.637082,
#  47.97847999999999,
#  46.344719999999995,
#  48.763943999999995,
#  46.617853999999994,
#  44.427313999999996,
#  46.57652000000001,
#  45.616350000000004,
#  43.682564,
#  49.768638,
#  48.17714,
#  43.661449999999995,
#  50.94627799999999,
#  49.345164,
#  49.539226,
#  46.88844,
#  47.31111800000001,
#  50.02772,
#  51.354474,
#  49.971289999999996,
#  50.78636,
#  47.66359799999999,
#  48.801984000000004,
#  42.403887999999995,
#  47.25198,
#  54.78407200000001,
#  45.133039999999994,
#  48.433915999999996,
#  46.063672000000004,
#  49.389154,
#  44.30401,
#  50.371995999999996,
#  49.813858,
#  47.887480000000004,
#  46.909346000000006,
#  49.548514000000004,
#  48.87084000000001,
#  46.02626600000001,
#  49.235936,
#  45.10008399999999,
#  50.759862000000005,
#  49.50004,
#  47.66092,
#  49.872200000000014,
#  45.562414,
#  46.758692,
#  47.811381999999995,
#  46.771800000000006,
#  48.19064,
#  48.56510599999999,
#  51.197700000000005,
#  46.69453999999999,
#  49.820132000000015,
#  48.67485599999999,
#  49.53748,
#  46.822932,
#  48.94323399999999,
#  49.030128,
#  48.916258,
#  46.22598000000001,
#  49.662102000000004,
#  50.401230000000005,
#  48.216440000000006,
#  50.3033,
#  46.15174,
#  48.76749000000001,
#  49.11528000000001,
#  47.04684,
#  49.144566000000005,
#  46.178639999999994,
#  47.257875999999996,
#  47.18335999999999,
#  46.05918800000001,
#  51.187380000000005,
#  44.642784,
#  47.698754,
#  46.43675999999999,
#  48.29568599999999,
#  47.85508,
#  50.355295999999996,
#  47.250659999999996,
#  51.202792,
#  48.033094,
#  45.50178,
#  46.135914000000014,
#  47.814595999999995,
#  47.916622,
#  48.93801799999999,
#  46.63521999999999,
#  47.29730599999999,
#  51.641000000000005,
#  46.397722,
#  52.703024000000006,
#  47.496140000000004,
#  45.204043999999996,
#  49.387184000000005,
#  47.83018000000001,
#  45.864208000000005,
#  48.696341999999994,
#  46.35182199999999,
#  47.601293999999996,
#  48.95915,
#  48.182608,
#  47.42508000000001,
#  48.493662,
#  48.17948000000001,
#  44.28786000000001,
#  45.546654,
#  41.470169999999996,
#  45.920500000000004,
#  48.933325999999994,
#  49.030692,
#  48.896384,
#  47.84436999999999,
#  47.849692,
#  48.268699999999995,
#  49.340058,
#  47.44273999999999,
#  47.34685600000001,
#  46.155056000000016,
#  52.357838,
#  46.34664000000001,
#  45.434259999999995,
#  45.3168,
#  45.35678000000001,
#  46.255368000000004,
#  46.598980000000005,
#  48.192457999999995,
#  48.82984,
#  46.584830000000004,
#  49.043964,
#  54.16604,
#  43.256172,
#  46.185531999999995,
#  47.316359999999996,
#  50.537796,
#  50.453199999999995,
#  49.668980000000005,
#  48.3385,
#  47.82808000000001,
#  44.226006000000005,
#  46.633882,
#  51.767548,
#  43.679368000000004,
#  52.45803999999999,
#  46.751174,
#  53.26544,
#  47.40503600000001,
#  47.962664000000004,
#  49.44880199999999,
#  49.457029999999996,
#  48.019951999999996,
#  46.144464000000006,
#  48.54152000000001,
#  48.432711999999995,
#  51.39778000000001,
#  46.42103999999999,
#  44.09635800000001,
#  47.74621199999999,
#  45.560649999999995,
#  48.713159999999995,
#  46.66515999999999,
#  44.06928,
#  45.23328200000001,
#  44.56718,
#  47.16832200000001,
#  47.252309999999994,
#  46.9768,
#  45.8679,
#  43.694832,
#  47.27948200000001,
#  49.324332000000005,
#  46.086119999999994,
#  45.40483999999999,
#  43.119735999999996,
#  47.793194,
#  53.62880000000001,
#  53.33267999999999,
#  49.78808599999999,
#  44.68785999999999,
#  45.8471,
#  43.96079399999999,
#  49.92992399999999,
#  48.967476000000005,
#  52.520813999999994,
#  48.569558,
#  46.644968000000006,
#  46.938480000000006,
#  45.90129000000001,
#  48.25713399999999,
#  46.286047999999994,
#  46.494968,
#  48.85479,
#  45.581499999999984,
#  43.927611999999996,
#  49.331323999999995,
#  50.78634,
#  51.87362800000001,
#  45.390622,
#  46.697636,
#  43.922132000000005,
#  46.301472,
#  45.67126000000001,
#  48.113240000000005,
#  46.931224,
#  48.43504,
#  49.51954799999999,
#  47.51760000000001,
#  47.43552999999999,
#  47.379360000000005,
#  45.05194,
#  44.828300000000006,
#  50.317840000000004,
#  45.552,
#  47.830887999999995,
#  47.595334,
#  43.952300000000015,
#  46.53052,
#  51.808488,
#  46.229772000000004,
#  46.38756,
#  48.48836400000001,
#  50.38098,
#  49.864064,
#  47.773532,
#  46.00702799999999,
#  47.952266,
#  47.782714,
#  50.57439600000001,
#  44.36733999999999,
#  46.45518199999999,
#  45.147200000000005,
#  46.222752,
#  49.40671,
#  49.480832,
#  49.092064,
#  48.105318,
#  47.657958,
#  46.074844000000006,
#  46.23160200000001,
#  48.48328199999999,
#  49.671864,
#  46.1043,
#  46.534682000000004,
#  49.01427399999999,
#  48.17083599999999,
#  47.838294,
#  46.624854,
#  46.665499999999994,
#  46.116068,
#  52.258158,
#  45.086099999999995,
#  46.139384,
#  47.420849999999994,
#  45.734159999999996,
#  45.829428,
#  47.219868000000005,
#  48.531658,
#  49.911834,
#  50.68463400000002,
#  48.367020000000004,
#  49.02564,
#  49.91286,
#  48.006454000000005,
#  47.56884000000001,
#  49.48754999999999,
#  44.249278000000004,
#  44.052796,
#  46.25795000000001,
#  46.642996000000004,
#  48.947176000000006,
#  48.591176000000004,
#  53.60234799999999,
#  47.319162000000006,
#  50.094634000000006,
#  49.534424,
#  46.038902,
#  46.49288000000001,
#  47.45673999999999,
#  47.129780000000004,
#  47.18660599999999,
#  44.333172000000005,
#  46.621359999999996,
#  51.98946599999999,
#  45.466566,
#  46.756091999999995,
#  46.778200000000005,
#  46.748476000000004,
#  44.51253200000001,
#  48.71155999999999,
#  45.23643800000001,
#  50.893968,
#  50.569399999999995,
#  50.444511999999996,
#  41.73929999999999,
#  49.764264,
#  47.22096,
#  50.812858,
#  52.528130000000004,
#  47.485666,
#  53.19860200000001,
#  46.538120000000006,
#  46.961096,
#  46.85936000000001,
#  46.587922,
#  47.805836,
#  45.500312,
#  49.28358,
#  49.72322,
#  48.11234,
#  44.401112000000005,
#  47.409459999999996,
#  47.03996,
#  44.268100000000004,
#  46.18280000000001,
#  47.93122,
#  50.46524,
#  49.390696,
#  48.18668,
#  50.787864,
#  47.729426,
#  46.244374,
#  49.857286,
#  50.06242,
#  45.64594,
#  47.91924,
#  47.12652,
#  47.99019999999999,
#  42.63822000000001,
#  46.665437999999995,
#  47.571574,
#  50.96558,
#  44.639359999999996,
#  49.552167999999995,
#  46.45604000000001,
#  49.405432,
#  50.85949200000001,
#  49.85273599999999,
#  48.904439999999994,
#  44.54616,
#  47.61273200000001,
#  50.611495999999995,
#  47.059376,
#  48.831992,
#  48.33328,
#  45.89083999999999,
#  47.97699799999999,
#  49.11094,
#  45.83384,
#  44.26027200000001,
#  48.747142000000004,
#  47.47794999999999,
#  46.975248,
#  49.43322000000001,
#  50.0373,
#  49.582084,
#  45.59758,
#  49.01023800000001,
#  50.368412,
#  46.896702,
#  44.442620000000005,
#  48.04714,
#  48.98844600000001,
#  48.209316,
#  48.03868000000001,
#  50.420066000000006,
#  48.521038,
#  47.352692,
#  48.350144,
#  49.80696000000001,
#  45.93606,
#  46.65572000000001]

# %%
df['HourlyRate'].hist(bins='auto')
# Out:
# <Axes: >

# %%
# Plotting the distribution of our samples, plus our pop and sample means
pop_mean = df['HourlyRate'].mean()
samp_mean = np.mean(sample_means)

plt.figure(figsize=(8,6))

sns.histplot(sample_means)

plt.vlines(pop_mean, ymin=0, ymax=25, color='r', linestyle=':',
           label=f'Population Mean: {pop_mean:.2f}')
plt.vlines(samp_mean, ymin=0, ymax=25, color='g', linestyle=':',
           label=f'Mean of {k} Samples: {samp_mean:.2f}')

plt.legend();

# %%
sns.kdeplot(df['HourlyRate']);

# %% [markdown]
# Discuss:
#
# - CLT at play, distribution of sample means is mostly normal (more than original)

# %% [markdown]
# -----
#
#
# # Level Up: Other Distributions

# %% [markdown]
# The world is full of distributions to explore! See some other less-common ones below:

# %% [markdown]
# ![](images/distributions.png)

# %% [markdown]
# Now that we know a few methods in visualizing distributions 📊👀, we can start looking at different types of distributions.
#
# We can tell a lot about a distribution shape such as taking a guess of the mechanism that it took to generate the data.

# %% [markdown]
# ## Level Up: SKLearn's Standard Scaler
#
# Soon we'll be using a pre-built function to scale our data: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
#
# Let's go ahead and peek at our first `sklearn` class!

# %%
df['num'] = 10

# %%
df['HourlyRate']
# Out:
# 0        53.740
# 1        39.780
# 2        29.450
# 3        29.450
# 4        97.164
#           ...
# 11734    41.450
# 11735    33.440
# 11736    33.440
# 11737    30.720
# 11738    29.450
# Name: HourlyRate, Length: 11739, dtype: float64

# %%
df['num']
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 11734    10
# 11735    10
# 11736    10
# 11737    10
# 11738    10
# Name: num, Length: 11739, dtype: int64

# %%
df[['HourlyRate', 'num']]
# Out:
#        HourlyRate  num
# 0          53.740   10
# 1          39.780   10
# 2          29.450   10
# 3          29.450   10
# 4          97.164   10
# ...           ...  ...
# 11734      41.450   10
# 11735      33.440   10
# 11736      33.440   10
# 11737      30.720   10
# 11738      29.450   10
#
# [11739 rows x 2 columns]

# %%
# Importing StandardScaler from the preprocessing module
from sklearn.preprocessing import StandardScaler

# Need to instantiate our scaler
scaler = StandardScaler()

# Fitting our scaler (note how we need to make the column into a dataframe)
scaler.fit(df[['HourlyRate']])

# Grabbing the transformed values out as scaled_rate
scaled_rate = scaler.transform(df[['HourlyRate']])

# %%
scaled_rate
# Out:
# array([[ 0.35419662],
#        [-0.48066092],
#        [-1.09843158],
#        ...,
#        [-0.85981542],
#        [-1.02248108],
#        [-1.09843158]])

# %%
scaler.fit_transform(df[['HourlyRate']])
# Out:
# array([[ 0.35419662],
#        [-0.48066092],
#        [-1.09843158],
#        ...,
#        [-0.85981542],
#        [-1.02248108],
#        [-1.09843158]])

# %%
scaler = StandardScaler()

# %%
type(scaler)
# Out:
# sklearn.preprocessing._data.StandardScaler

# %%
scaler.mean_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 scaler.mean_
#
# AttributeError: 'StandardScaler' object has no attribute 'mean_'

# %%
scaler.fit(df[['HourlyRate', 'num']])
# Out:
# StandardScaler()

# %%
df['HourlyRate'].mean()
# Out:
# 47.81733114404976

# %%
scaler.mean_
# Out:
# array([47.81733114, 10.        ])

# %%
scaler.scale_
# Out:
# array([16.72141574,  1.        ])

# %%
scaler.transform(df[['HourlyRate', 'num']])
# Out:
# array([[ 0.35419662,  0.        ],
#        [-0.48066092,  0.        ],
#        [-1.09843158,  0.        ],
#        ...,
#        [-0.85981542,  0.        ],
#        [-1.02248108,  0.        ],
#        [-1.09843158,  0.        ]])

# %%
# Plot and compare results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize=(10,6), sharex=True)

sns.kdeplot(df['HourlyRate'], ax=ax1, label='Without Scaling')
ax1.legend()

sns.kdeplot(standardized_rate, ax=ax2, label='Manual Scaling')
ax2.legend()

sns.kdeplot(scaled_rate[:,0], ax=ax3, label='SKLearn Standard Scaling')
ax3.legend()

plt.show()

# %%
heart_df = pd.read_csv('../../Phase1/Lectures/data/heart.csv')

# %%
heart_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
scaler2 = StandardScaler()

# %%
scaler2.fit(heart_df)
# Out:
# StandardScaler()

# %%
scaler2.mean_
# Out:
# array([5.43663366e+01, 6.83168317e-01, 9.66996700e-01, 1.31623762e+02,
#        2.46264026e+02, 1.48514851e-01, 5.28052805e-01, 1.49646865e+02,
#        3.26732673e-01, 1.03960396e+00, 1.39933993e+00, 7.29372937e-01,
#        2.31353135e+00, 5.44554455e-01])

# %%
scaler2.transform(heart_df)
# Out:
# array([[ 0.9521966 ,  0.68100522,  1.97312292, ..., -0.71442887,
#         -2.14887271,  0.91452919],
#        [-1.91531289,  0.68100522,  1.00257707, ..., -0.71442887,
#         -0.51292188,  0.91452919],
#        [-1.47415758, -1.46841752,  0.03203122, ..., -0.71442887,
#         -0.51292188,  0.91452919],
#        ...,
#        [ 1.50364073,  0.68100522, -0.93851463, ...,  1.24459328,
#          1.12302895, -1.09345881],
#        [ 0.29046364,  0.68100522, -0.93851463, ...,  0.26508221,
#          1.12302895, -1.09345881],
#        [ 0.29046364, -1.46841752,  0.03203122, ...,  0.26508221,
#         -0.51292188, -1.09345881]])

# %%
pd.DataFrame(scaler2.transform(heart_df), columns=heart_df.columns)
# Out:
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    0.952197  0.681005  1.973123  0.763956 -0.256334  2.394438 -1.005832
# 1   -1.915313  0.681005  1.002577 -0.092738  0.072199 -0.417635  0.898962
# 2   -1.474158 -1.468418  0.032031 -0.092738 -0.816773 -0.417635 -1.005832
# 3    0.180175  0.681005  0.032031 -0.663867 -0.198357 -0.417635  0.898962
# 4    0.290464 -1.468418 -0.938515 -0.663867  2.082050 -0.417635  0.898962
# ..        ...       ...       ...       ...       ...       ...       ...
# 298  0.290464 -1.468418 -0.938515  0.478391 -0.101730 -0.417635  0.898962
# 299 -1.033002  0.681005  1.973123 -1.234996  0.342756 -0.417635  0.898962
# 300  1.503641  0.681005 -0.938515  0.706843 -1.029353  2.394438  0.898962
# 301  0.290464  0.681005 -0.938515 -0.092738 -2.227533 -0.417635  0.898962
# 302  0.290464 -1.468418  0.032031 -0.092738 -0.198357 -0.417635 -1.005832
#
#       thalach     exang   oldpeak     slope        ca      thal    target
# 0    0.015443 -0.696631  1.087338 -2.274579 -0.714429 -2.148873  0.914529
# 1    1.633471 -0.696631  2.122573 -2.274579 -0.714429 -0.512922  0.914529
# 2    0.977514 -0.696631  0.310912  0.976352 -0.714429 -0.512922  0.914529
# 3    1.239897 -0.696631 -0.206705  0.976352 -0.714429 -0.512922  0.914529
# 4    0.583939  1.435481 -0.379244  0.976352 -0.714429 -0.512922  0.914529
# ..        ...       ...       ...       ...       ...       ...       ...
# 298 -1.165281  1.435481 -0.724323 -0.649113 -0.714429  1.123029 -1.093459
# 299 -0.771706 -0.696631  0.138373 -0.649113 -0.714429  1.123029 -1.093459
# 300 -0.378132 -0.696631  2.036303 -0.649113  1.244593  1.123029 -1.093459
# 301 -1.515125  1.435481  0.138373 -0.649113  0.265082  1.123029 -1.093459
# 302  1.064975 -0.696631 -0.896862 -0.649113  0.265082 -0.512922 -1.093459
#
# [303 rows x 14 columns]
